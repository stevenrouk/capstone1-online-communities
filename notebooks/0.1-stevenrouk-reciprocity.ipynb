# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Modifying the path so we can import from src directory.
import sys
import os
sys.path.append(os.path.abspath('..'))

from collections import Counter, defaultdict
from itertools import chain
import copy
import pickle
import random
import time

import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
from pyvis.network import Network

from src.example_graphs import simple_undirected_graph, simple_directed_graph
from src.UndirectedGraph import UndirectedGraph
from src.DirectedGraph import DirectedGraph
from src.DataLoader import DataLoader
from src.GraphCreator import GraphCreator, NetworkXGraphCreator

from src.io_helpers import pickle_obj, load_pickled_obj
from src.networkx_helpers import combine_graphs
from src.networkx_multigraph_helpers import (get_edge_attrs, aggregate_numeric_properties,
                                             sum_numeric_properties, count_edges,
                                             sharing_reciprocity)

# %%
ROOT_DIRECTORY = os.path.split(os.getcwd())[0]
DATA_DIRECTORY = os.path.join(ROOT_DIRECTORY, 'data')
PICKLED_DATA_DIRECTORY = os.path.join(ROOT_DIRECTORY, 'data_pickle')

# %% [markdown]
# ### Load our G_weighted graph

# %%
G_weighted = load_pickled_obj(os.path.join(PICKLED_DATA_DIRECTORY, 'networkx_weighted_full.pickle'))

# %% [markdown]
# # Looking at Sharing Reciprocity
# ### First, let's look at a subset of our graph.

# %%
G_weighted_subset = G_weighted.edge_subgraph(G_weighted.edges('vegan'))

# %%
G_weighted_subset['vegan']['worldnews']
# Out:
# {'weight': 26}

# %%
sharing_reciprocity(G_weighted_subset, 'vegan', 'worldnews')
# Out:
# {'reciprocity': 1.0, 'summed weights': 26, 'n-to-m': 26, 'm_to_n': 0}

# %%
reciprocities = []
focus_node = 'vegan'
for neighbor_node in G_weighted_subset[focus_node]:
    reciprocities.append((neighbor_node, sharing_reciprocity(G_weighted, focus_node, neighbor_node)))

# %%
sorted(reciprocities, key=lambda x: x[1]['summed weights'], reverse=True)
# Out:
# [('askreddit',
#   {'reciprocity': 1.0, 'summed weights': 57, 'n-to-m': 57, 'm_to_n': 0}),
#  ('vegancirclejerk',
#   {'reciprocity': 0.05263157894736842,
#    'summed weights': 38,
#    'n-to-m': 2,
#    'm_to_n': 36}),
#  ('iama',
#   {'reciprocity': 1.0, 'summed weights': 36, 'n-to-m': 36, 'm_to_n': 0}),
#  ('news',
#   {'reciprocity': 1.0, 'summed weights': 33, 'n-to-m': 33, 'm_to_n': 0}),
#  ('todayilearned',
#   {'reciprocity': 1.0, 'summed weights': 32, 'n-to-m': 32, 'm_to_n': 0}),
#  ('worldnews',
#   {'reciprocity': 0.9629629629629629,
#    'summed weights': 27,
#    'n-to-m': 26,
#    'm_to_n': 1}),
#  ('science',
#   {'reciprocity': 1.0, 'summed weights': 23, 'n-to-m': 23, 'm_to_n': 0}),
#  ('subredditdrama',
#   {'reciprocity': 0.08695652173913043,
#    'summed weights': 23,
#    'n-to-m': 2,
#    'm_to_n': 21}),
#  ('videos',
#   {'reciprocity': 0.9545454545454546,
#    'summed weights': 22,
#    'n-to-m': 21,
#    'm_to_n': 1}),
#  ('philosophy',
#   {'reciprocity': 1.0, 'summed weights': 20, 'n-to-m': 20, 'm_to_n': 0}),
#  ('vegetarian',
#   {'reciprocity': 0.3157894736842105,
#    'summed weights': 19,
#    'n-to-m': 6,
#    'm_to_n': 13}),
#  ('funny',
#   {'reciprocity': 0.9411764705882353,
#    'summed weights': 17,
#    'n-to-m': 16,
#    'm_to_n': 1}),
#  ('changemyview',
#   {'reciprocity': 0.9375, 'summed weights': 16, 'n-to-m': 15, 'm_to_n': 1}),
#  ('wtf',
#   {'reciprocity': 1.0, 'summed weights': 15, 'n-to-m': 15, 'm_to_n': 0}),
#  ('aww',
#   {'reciprocity': 0.9285714285714286,
#    'summed weights': 14,
#    'n-to-m': 13,
#    'm_to_n': 1}),
#  ('bestof',
#   {'reciprocity': 0.15384615384615385,
#    'summed weights': 13,
#    'n-to-m': 2,
#    'm_to_n': 11}),
#  ('adviceanimals',
#   {'reciprocity': 1.0, 'summed weights': 11, 'n-to-m': 11, 'm_to_n': 0}),
#  ('pics',
#   {'reciprocity': 0.9090909090909091,
#    'summed weights': 11,
#    'n-to-m': 10,
#    'm_to_n': 1}),
#  ('documentaries',
#   {'reciprocity': 1.0, 'summed weights': 10, 'n-to-m': 10, 'm_to_n': 0}),
#  ('futurology',
#   {'reciprocity': 0.9, 'summed weights': 10, 'n-to-m': 9, 'm_to_n': 1}),
#  ('truereddit',
#   {'reciprocity': 1.0, 'summed weights': 10, 'n-to-m': 10, 'm_to_n': 0}),
#  ('food',
#   {'reciprocity': 0.8888888888888888,
#    'summed weights': 9,
#    'n-to-m': 8,
#    'm_to_n': 1}),
#  ('veganfitness',
#   {'reciprocity': 0.25, 'summed weights': 8, 'n-to-m': 2, 'm_to_n': 6}),
#  ('tumblrinaction',
#   {'reciprocity': 0.875, 'summed weights': 8, 'n-to-m': 7, 'm_to_n': 1}),
#  ('veganarchism',
#   {'reciprocity': 0.25, 'summed weights': 8, 'n-to-m': 2, 'm_to_n': 6}),
#  ('gifs', {'reciprocity': 1.0, 'summed weights': 7, 'n-to-m': 7, 'm_to_n': 0}),
#  ('environment',
#   {'reciprocity': 1.0, 'summed weights': 7, 'n-to-m': 7, 'm_to_n': 0}),
#  ('veganrecipes',
#   {'reciprocity': 0.5, 'summed weights': 6, 'n-to-m': 3, 'm_to_n': 3}),
#  ('explainlikeimfive',
#   {'reciprocity': 1.0, 'summed weights': 6, 'n-to-m': 6, 'm_to_n': 0}),
#  ('showerthoughts',
#   {'reciprocity': 1.0, 'summed weights': 5, 'n-to-m': 5, 'm_to_n': 0}),
#  ('keto', {'reciprocity': 0.2, 'summed weights': 5, 'n-to-m': 1, 'm_to_n': 4}),
#  ('atheism',
#   {'reciprocity': 0.8, 'summed weights': 5, 'n-to-m': 4, 'm_to_n': 1}),
#  ('askphilosophy',
#   {'reciprocity': 0.8, 'summed weights': 5, 'n-to-m': 4, 'm_to_n': 1}),
#  ('veganscience',
#   {'reciprocity': 0.25, 'summed weights': 4, 'n-to-m': 1, 'm_to_n': 3}),
#  ('eatcheapandhealthy',
#   {'reciprocity': 1.0, 'summed weights': 4, 'n-to-m': 4, 'm_to_n': 0}),
#  ('health',
#   {'reciprocity': 1.0, 'summed weights': 4, 'n-to-m': 4, 'm_to_n': 0}),
#  ('politics',
#   {'reciprocity': 1.0, 'summed weights': 4, 'n-to-m': 4, 'm_to_n': 0}),
#  ('trueaskreddit',
#   {'reciprocity': 1.0, 'summed weights': 4, 'n-to-m': 4, 'm_to_n': 0}),
#  ('cringeanarchy',
#   {'reciprocity': 0.5, 'summed weights': 4, 'n-to-m': 2, 'm_to_n': 2}),
#  ('mildlyinteresting',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('rage',
#   {'reciprocity': 0.6666666666666666,
#    'summed weights': 3,
#    'n-to-m': 2,
#    'm_to_n': 1}),
#  ('relationships',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('running',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('indianfood',
#   {'reciprocity': 0.6666666666666666,
#    'summed weights': 3,
#    'n-to-m': 2,
#    'm_to_n': 1}),
#  ('anarchism',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('standupshots',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('dogs', {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('tifu', {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('glutenfreevegan',
#   {'reciprocity': 0.6666666666666666,
#    'summed weights': 3,
#    'n-to-m': 2,
#    'm_to_n': 1}),
#  ('facepalm',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('anticonsumption',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('art',
#   {'reciprocity': 0.3333333333333333,
#    'summed weights': 3,
#    'n-to-m': 1,
#    'm_to_n': 2}),
#  ('writingprompts',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('india',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('latestagecapitalism',
#   {'reciprocity': 0.3333333333333333,
#    'summed weights': 3,
#    'n-to-m': 1,
#    'm_to_n': 2}),
#  ('veganrights',
#   {'reciprocity': 0.3333333333333333,
#    'summed weights': 3,
#    'n-to-m': 1,
#    'm_to_n': 2}),
#  ('nottheonion',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('woahdude',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('skincareaddiction',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('vegrecipes',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('subredditsmeet',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('conspiracy',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('vegantechs',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('fitness',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('veganbeauty',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('trollxchromosomes',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('canada',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('cooking',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('nostupidquestions',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('movies',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('asianbeauty',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('thenetherlands',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('zerowaste',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('askmen',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('washingtondc',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('okcupid',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('femalefashionadvice',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('foodforthought',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('jokes',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('buddhism',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('paleo',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('exmuslim',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('fitmeals',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('samplesize',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('northcarolina',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('france',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('veghumor',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('nutrition',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('comics',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('skeptic',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('theydidthemath',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('plantbaseddiet',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('casualconversation',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('progresspics',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('unitedkingdom',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('veganpizza',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('topmindsofreddit',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('cringepics',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('askvet',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('gatekeeping',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('starbucks',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('frugal',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('calgary',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('offmychest',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('weddingplanning',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('beautyboxes',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('pets', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('holdmybeer',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('bojackhorseman',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('spain',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganbookclub',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('subredditads',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('getmotivated',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('climbing',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('microdosing',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('lsd', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('askwomen',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sneks',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('humansbeingbros',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sri', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('quittingkratom',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('childfree',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('religion',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('reactiongifs',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('offbeat',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('vegangaming',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('pokemongo',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('animalsbeingjerks',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('creepy',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganinjapan',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('xxfitness',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('asksciencediscussion',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('haiku',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('wholesomememes',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('nonfictionbookclub',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('books',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('tacobell',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('survivor',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('guitar',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('askscience',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('gmohealth',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('entertainment',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('debatereligion',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('justiceporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sweden',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('foodporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('watchingcongress',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('diy', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('dayz', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('debateanarchism',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('bipolar',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('snackexchange',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('batman',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('farming',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('china',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('fantasy',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('orlando',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('blackladies',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('b12', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('educationalgifs',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('crazyideas',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('psychonaut',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('truefilm',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('makeupexchange',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('dubbedgifs',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('greece',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('australia',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('adhd', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('neworleans',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('cynicalbrit',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('lectures',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('caminodesantiago',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('propagandaposters',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganismo',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('monsterhunter',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('losangeles',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sanfrancisco',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('topgear',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('ahegao',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('babyelephantgifs',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('television',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('toronto',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('selfsufficiency',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('everythingscience',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('atlanta',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('technology',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('orangecounty',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('soylent',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('europe',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('editingandlayout',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('shortscarystories',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('eesti',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('interiordesign',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('equestrian',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('oakland',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('casualiama',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('tumblr',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('oney', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('masterchef',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('rabbits',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('oldschoolcool',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('legaladvice',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('beamazed',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('fantasyfootball',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('mbti', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('assistance',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('melbourne',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('ramen',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veggiefriendly',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('simpleliving',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('pcos', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('bodybuilding',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veg', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('longtail',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('tumblrpls',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('upliftingnews',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('anarcho_capitalism',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('humor',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('nonononoyes',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('youshouldknow',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('mma', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('quityourbullshit',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sandersforpresident',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('daddit',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('explainlikeiama',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('humanporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('pizza',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('earthporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('loseit',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('horriblydepressing',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('advice',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('shittylifeprotips',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('ethicalbuying',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('advancedfitness',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('oddlysatisfying',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('threadkillers',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('pcmasterrace',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('imgoingtohellforthis',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('askmenover30',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('dadjokes',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('unexpected',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('the_donald',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('colonizemars',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('shittyfoodporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('backyardchickens',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('againstpetownership',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('supplements',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('kitchenconfidential',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('askvegans',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('roastme',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('freebies',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('babyledweaning',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganuk',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganfoodporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('confessions',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('rant', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('animalsbeingderps',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('gaming',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('confession',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('interestingasfuck',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('israel',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('quotesporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sex', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('zerocarb',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('saplings',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('ketogains',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('philadelphia',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('wewantplates',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('vegan_food',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('dataisbeautiful',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('rarepuppers',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('stopspeciesism',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('alcohol',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0})]

# %%
sorted(reciprocities, key=lambda x: x[1]['reciprocity'], reverse=True)
# Out:
# [('woahdude',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('iama',
#   {'reciprocity': 1.0, 'summed weights': 36, 'n-to-m': 36, 'm_to_n': 0}),
#  ('frugal',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('science',
#   {'reciprocity': 1.0, 'summed weights': 23, 'n-to-m': 23, 'm_to_n': 0}),
#  ('todayilearned',
#   {'reciprocity': 1.0, 'summed weights': 32, 'n-to-m': 32, 'm_to_n': 0}),
#  ('adviceanimals',
#   {'reciprocity': 1.0, 'summed weights': 11, 'n-to-m': 11, 'm_to_n': 0}),
#  ('calgary',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('offmychest',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('news',
#   {'reciprocity': 1.0, 'summed weights': 33, 'n-to-m': 33, 'm_to_n': 0}),
#  ('wtf',
#   {'reciprocity': 1.0, 'summed weights': 15, 'n-to-m': 15, 'm_to_n': 0}),
#  ('weddingplanning',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('askreddit',
#   {'reciprocity': 1.0, 'summed weights': 57, 'n-to-m': 57, 'm_to_n': 0}),
#  ('beautyboxes',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('mildlyinteresting',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('pets', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('gifs', {'reciprocity': 1.0, 'summed weights': 7, 'n-to-m': 7, 'm_to_n': 0}),
#  ('holdmybeer',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('bojackhorseman',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('spain',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganbookclub',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('skincareaddiction',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('subredditads',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('getmotivated',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('subredditsmeet',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('conspiracy',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('eatcheapandhealthy',
#   {'reciprocity': 1.0, 'summed weights': 4, 'n-to-m': 4, 'm_to_n': 0}),
#  ('climbing',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('microdosing',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('lsd', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('askwomen',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('relationships',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('sneks',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('humansbeingbros',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('running',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('sri', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('fitness',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('documentaries',
#   {'reciprocity': 1.0, 'summed weights': 10, 'n-to-m': 10, 'm_to_n': 0}),
#  ('quittingkratom',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('health',
#   {'reciprocity': 1.0, 'summed weights': 4, 'n-to-m': 4, 'm_to_n': 0}),
#  ('childfree',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('trollxchromosomes',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('showerthoughts',
#   {'reciprocity': 1.0, 'summed weights': 5, 'n-to-m': 5, 'm_to_n': 0}),
#  ('religion',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('reactiongifs',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('offbeat',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('vegangaming',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('pokemongo',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('environment',
#   {'reciprocity': 1.0, 'summed weights': 7, 'n-to-m': 7, 'm_to_n': 0}),
#  ('animalsbeingjerks',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('philosophy',
#   {'reciprocity': 1.0, 'summed weights': 20, 'n-to-m': 20, 'm_to_n': 0}),
#  ('creepy',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganinjapan',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('canada',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('cooking',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('xxfitness',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('asksciencediscussion',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('nostupidquestions',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('haiku',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('movies',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('wholesomememes',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('nonfictionbookclub',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('books',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('tacobell',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('thenetherlands',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('survivor',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('guitar',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('askscience',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('gmohealth',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('entertainment',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('politics',
#   {'reciprocity': 1.0, 'summed weights': 4, 'n-to-m': 4, 'm_to_n': 0}),
#  ('askmen',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('debatereligion',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('justiceporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sweden',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('truereddit',
#   {'reciprocity': 1.0, 'summed weights': 10, 'n-to-m': 10, 'm_to_n': 0}),
#  ('foodporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('watchingcongress',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('diy', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('dayz', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('debateanarchism',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('washingtondc',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('bipolar',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('snackexchange',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('batman',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('farming',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('china',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('fantasy',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('orlando',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('okcupid',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('femalefashionadvice',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('blackladies',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('b12', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('educationalgifs',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('crazyideas',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('anarchism',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('psychonaut',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('foodforthought',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('truefilm',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('standupshots',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('jokes',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('dogs', {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('buddhism',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('paleo',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('exmuslim',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('makeupexchange',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('tifu', {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('dubbedgifs',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('greece',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('australia',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('adhd', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('fitmeals',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('explainlikeimfive',
#   {'reciprocity': 1.0, 'summed weights': 6, 'n-to-m': 6, 'm_to_n': 0}),
#  ('neworleans',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('cynicalbrit',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('lectures',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('caminodesantiago',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('propagandaposters',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('samplesize',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('veganismo',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('monsterhunter',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('losangeles',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sanfrancisco',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('topgear',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('facepalm',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('anticonsumption',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('ahegao',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('babyelephantgifs',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('television',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('toronto',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('selfsufficiency',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('everythingscience',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('atlanta',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('northcarolina',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('technology',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('orangecounty',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('france',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('soylent',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('trueaskreddit',
#   {'reciprocity': 1.0, 'summed weights': 4, 'n-to-m': 4, 'm_to_n': 0}),
#  ('europe',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('editingandlayout',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('shortscarystories',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('eesti',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('interiordesign',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('equestrian',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('oakland',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('comics',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('skeptic',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('casualiama',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('tumblr',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('oney', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('masterchef',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('rabbits',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('writingprompts',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('oldschoolcool',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('legaladvice',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('theydidthemath',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('beamazed',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('fantasyfootball',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('mbti', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('india',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('assistance',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('melbourne',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('ramen',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veggiefriendly',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('simpleliving',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('pcos', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('bodybuilding',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veg', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('longtail',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('tumblrpls',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('upliftingnews',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('anarcho_capitalism',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('casualconversation',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('humor',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('progresspics',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('nonononoyes',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('youshouldknow',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('mma', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('quityourbullshit',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sandersforpresident',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('daddit',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('explainlikeiama',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('humanporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('nottheonion',
#   {'reciprocity': 1.0, 'summed weights': 3, 'n-to-m': 3, 'm_to_n': 0}),
#  ('pizza',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('earthporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('unitedkingdom',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('loseit',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('horriblydepressing',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('advice',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('shittylifeprotips',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganpizza',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('ethicalbuying',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('advancedfitness',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('oddlysatisfying',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('threadkillers',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('pcmasterrace',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('imgoingtohellforthis',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('askmenover30',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('dadjokes',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('unexpected',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('the_donald',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('colonizemars',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('shittyfoodporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('backyardchickens',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('againstpetownership',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('supplements',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('kitchenconfidential',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('askvegans',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('roastme',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('freebies',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('babyledweaning',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganuk',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('veganfoodporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('confessions',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('rant', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('animalsbeingderps',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('gaming',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('gatekeeping',
#   {'reciprocity': 1.0, 'summed weights': 2, 'n-to-m': 2, 'm_to_n': 0}),
#  ('confession',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('interestingasfuck',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('israel',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('quotesporn',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('sex', {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('zerocarb',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('saplings',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('ketogains',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('philadelphia',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('wewantplates',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('vegan_food',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('dataisbeautiful',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('rarepuppers',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('stopspeciesism',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('alcohol',
#   {'reciprocity': 1.0, 'summed weights': 1, 'n-to-m': 1, 'm_to_n': 0}),
#  ('worldnews',
#   {'reciprocity': 0.9629629629629629,
#    'summed weights': 27,
#    'n-to-m': 26,
#    'm_to_n': 1}),
#  ('videos',
#   {'reciprocity': 0.9545454545454546,
#    'summed weights': 22,
#    'n-to-m': 21,
#    'm_to_n': 1}),
#  ('funny',
#   {'reciprocity': 0.9411764705882353,
#    'summed weights': 17,
#    'n-to-m': 16,
#    'm_to_n': 1}),
#  ('changemyview',
#   {'reciprocity': 0.9375, 'summed weights': 16, 'n-to-m': 15, 'm_to_n': 1}),
#  ('aww',
#   {'reciprocity': 0.9285714285714286,
#    'summed weights': 14,
#    'n-to-m': 13,
#    'm_to_n': 1}),
#  ('pics',
#   {'reciprocity': 0.9090909090909091,
#    'summed weights': 11,
#    'n-to-m': 10,
#    'm_to_n': 1}),
#  ('futurology',
#   {'reciprocity': 0.9, 'summed weights': 10, 'n-to-m': 9, 'm_to_n': 1}),
#  ('food',
#   {'reciprocity': 0.8888888888888888,
#    'summed weights': 9,
#    'n-to-m': 8,
#    'm_to_n': 1}),
#  ('tumblrinaction',
#   {'reciprocity': 0.875, 'summed weights': 8, 'n-to-m': 7, 'm_to_n': 1}),
#  ('atheism',
#   {'reciprocity': 0.8, 'summed weights': 5, 'n-to-m': 4, 'm_to_n': 1}),
#  ('askphilosophy',
#   {'reciprocity': 0.8, 'summed weights': 5, 'n-to-m': 4, 'm_to_n': 1}),
#  ('rage',
#   {'reciprocity': 0.6666666666666666,
#    'summed weights': 3,
#    'n-to-m': 2,
#    'm_to_n': 1}),
#  ('indianfood',
#   {'reciprocity': 0.6666666666666666,
#    'summed weights': 3,
#    'n-to-m': 2,
#    'm_to_n': 1}),
#  ('glutenfreevegan',
#   {'reciprocity': 0.6666666666666666,
#    'summed weights': 3,
#    'n-to-m': 2,
#    'm_to_n': 1}),
#  ('vegrecipes',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('vegantechs',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('veganbeauty',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('veganrecipes',
#   {'reciprocity': 0.5, 'summed weights': 6, 'n-to-m': 3, 'm_to_n': 3}),
#  ('asianbeauty',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('zerowaste',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('veghumor',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('nutrition',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('cringeanarchy',
#   {'reciprocity': 0.5, 'summed weights': 4, 'n-to-m': 2, 'm_to_n': 2}),
#  ('plantbaseddiet',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('topmindsofreddit',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('cringepics',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('askvet',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('starbucks',
#   {'reciprocity': 0.5, 'summed weights': 2, 'n-to-m': 1, 'm_to_n': 1}),
#  ('art',
#   {'reciprocity': 0.3333333333333333,
#    'summed weights': 3,
#    'n-to-m': 1,
#    'm_to_n': 2}),
#  ('latestagecapitalism',
#   {'reciprocity': 0.3333333333333333,
#    'summed weights': 3,
#    'n-to-m': 1,
#    'm_to_n': 2}),
#  ('veganrights',
#   {'reciprocity': 0.3333333333333333,
#    'summed weights': 3,
#    'n-to-m': 1,
#    'm_to_n': 2}),
#  ('vegetarian',
#   {'reciprocity': 0.3157894736842105,
#    'summed weights': 19,
#    'n-to-m': 6,
#    'm_to_n': 13}),
#  ('veganfitness',
#   {'reciprocity': 0.25, 'summed weights': 8, 'n-to-m': 2, 'm_to_n': 6}),
#  ('veganscience',
#   {'reciprocity': 0.25, 'summed weights': 4, 'n-to-m': 1, 'm_to_n': 3}),
#  ('veganarchism',
#   {'reciprocity': 0.25, 'summed weights': 8, 'n-to-m': 2, 'm_to_n': 6}),
#  ('keto', {'reciprocity': 0.2, 'summed weights': 5, 'n-to-m': 1, 'm_to_n': 4}),
#  ('bestof',
#   {'reciprocity': 0.15384615384615385,
#    'summed weights': 13,
#    'n-to-m': 2,
#    'm_to_n': 11}),
#  ('subredditdrama',
#   {'reciprocity': 0.08695652173913043,
#    'summed weights': 23,
#    'n-to-m': 2,
#    'm_to_n': 21}),
#  ('vegancirclejerk',
#   {'reciprocity': 0.05263157894736842,
#    'summed weights': 38,
#    'n-to-m': 2,
#    'm_to_n': 36})]

# %% [markdown]
# ## Now, let's calculate reciprocities for the whole graph

# %%
full_reciprocities = []
for focus_node in G_weighted:
    for neighbor_node in G_weighted[focus_node]:
        full_reciprocities.append({
            'focus_node': focus_node,
            'neighbor_node': neighbor_node,
            'reciprocity_dict': sharing_reciprocity(G_weighted, focus_node, neighbor_node)
        })

# %%
len(full_reciprocities)
# Out:
# 339643

# %%
len(G_weighted)
# Out:
# 67180

# %%
full_reciprocities[0]
# Out:
# {'focus_node': 'leagueoflegends',
#  'neighbor_node': 'teamredditteams',
#  'reciprocity_dict': {'reciprocity': 0.6,
#   'summed weights': 65,
#   'n-to-m': 39,
#   'm_to_n': 26}}

# %%
full_reciprocities[0]['reciprocity_dict']['reciprocity']
# Out:
# 0.6

# %% [markdown]
# ## Looking at middling reciprocities

# %%
# Let's look where reciprocities are between 0.4 and 0.6
middling_reciprocities = [edge for edge in full_reciprocities if abs(edge['reciprocity_dict']['reciprocity']-0.5)<0.1]

# %%
len(middling_reciprocities)
# Out:
# 28182

# %%
middling_reciprocities[:3]
# Out:
# [{'focus_node': 'leagueoflegends',
#   'neighbor_node': 'teamredditteams',
#   'reciprocity_dict': {'reciprocity': 0.6,
#    'summed weights': 65,
#    'n-to-m': 39,
#    'm_to_n': 26}},
#  {'focus_node': 'leagueoflegends',
#   'neighbor_node': 'lolchampconcepts',
#   'reciprocity_dict': {'reciprocity': 0.5384615384615384,
#    'summed weights': 39,
#    'n-to-m': 21,
#    'm_to_n': 18}},
#  {'focus_node': 'leagueoflegends',
#   'neighbor_node': 'dogecoin',
#   'reciprocity_dict': {'reciprocity': 0.5,
#    'summed weights': 4,
#    'n-to-m': 2,
#    'm_to_n': 2}}]

# %% [markdown]
# ## Now, let's look where the summed_weight is greater than some amount (people sharing a lot about the other)

# %%
middling_reciprocities_sum_gt_20 = [edge for edge in middling_reciprocities if edge['reciprocity_dict']['summed weights']>20]
len(middling_reciprocities_sum_gt_20)
# Out:
# 896

# %%
middling_reciprocities_sum_gt_50 = [edge for edge in middling_reciprocities if edge['reciprocity_dict']['summed weights']>50]
len(middling_reciprocities_sum_gt_50)
# Out:
# 234

# %%
middling_reciprocities_sum_gt_100 = [edge for edge in middling_reciprocities if edge['reciprocity_dict']['summed weights']>100]
len(middling_reciprocities_sum_gt_100)
# Out:
# 68

# %% [markdown]
# Since each edge will be doubled here (since reciprocity is two-way), there are 34 subreddit relationships where people share a lot about each other and the sharing is about equal.

# %%
sorted(middling_reciprocities_sum_gt_100, key=lambda x: x['reciprocity_dict']['summed weights'], reverse=True)[:10]
# Out:
# [{'focus_node': 'buildapc',
#   'neighbor_node': 'techsupport',
#   'reciprocity_dict': {'reciprocity': 0.47863247863247865,
#    'summed weights': 351,
#    'n-to-m': 168,
#    'm_to_n': 183}},
#  {'focus_node': 'techsupport',
#   'neighbor_node': 'buildapc',
#   'reciprocity_dict': {'reciprocity': 0.5213675213675214,
#    'summed weights': 351,
#    'n-to-m': 183,
#    'm_to_n': 168}},
#  {'focus_node': 'destinythegame',
#   'neighbor_node': 'crucibleplaybook',
#   'reciprocity_dict': {'reciprocity': 0.46153846153846156,
#    'summed weights': 286,
#    'n-to-m': 132,
#    'm_to_n': 154}},
#  {'focus_node': 'crucibleplaybook',
#   'neighbor_node': 'destinythegame',
#   'reciprocity_dict': {'reciprocity': 0.5384615384615384,
#    'summed weights': 286,
#    'n-to-m': 154,
#    'm_to_n': 132}},
#  {'focus_node': 'subredditdrama',
#   'neighbor_node': 'drama',
#   'reciprocity_dict': {'reciprocity': 0.46,
#    'summed weights': 250,
#    'n-to-m': 115,
#    'm_to_n': 135}},
#  {'focus_node': 'drama',
#   'neighbor_node': 'subredditdrama',
#   'reciprocity_dict': {'reciprocity': 0.54,
#    'summed weights': 250,
#    'n-to-m': 135,
#    'm_to_n': 115}},
#  {'focus_node': 'hearthstone',
#   'neighbor_node': 'competitivehs',
#   'reciprocity_dict': {'reciprocity': 0.5232067510548524,
#    'summed weights': 237,
#    'n-to-m': 124,
#    'm_to_n': 113}},
#  {'focus_node': 'competitivehs',
#   'neighbor_node': 'hearthstone',
#   'reciprocity_dict': {'reciprocity': 0.4767932489451477,
#    'summed weights': 237,
#    'n-to-m': 113,
#    'm_to_n': 124}},
#  {'focus_node': 'smashbros',
#   'neighbor_node': 'ssbpm',
#   'reciprocity_dict': {'reciprocity': 0.4716981132075472,
#    'summed weights': 212,
#    'n-to-m': 100,
#    'm_to_n': 112}},
#  {'focus_node': 'ssbpm',
#   'neighbor_node': 'smashbros',
#   'reciprocity_dict': {'reciprocity': 0.5283018867924528,
#    'summed weights': 212,
#    'n-to-m': 112,
#    'm_to_n': 100}}]

# %% [markdown]
# ## Now let's look at people who are ignored

# %%
# Ignored, but not quite totally ignored
ignored = [edge for edge in full_reciprocities if edge['reciprocity_dict']['reciprocity']>0.9 and edge['reciprocity_dict']['reciprocity']<1]

# %%
len(ignored)
# Out:
# 1423

# %%
totally_ignored = [edge for edge in full_reciprocities if edge['reciprocity_dict']['reciprocity']==1]

# %%
len(totally_ignored)
# Out:
# 279691

# %% [markdown]
# ### Now, let's look at people who share a lot about the other and are still ignored
#
# _**Actually not sure if it's "ignored" or if it should be called "gossipy".**_

# %%
# Ignored
print(len([edge for edge in ignored if edge['reciprocity_dict']['summed weights']>50]))
print(len([edge for edge in ignored if edge['reciprocity_dict']['summed weights']>100]))
print(len([edge for edge in ignored if edge['reciprocity_dict']['summed weights']>200]))
# Out:
# 342
# 140
# 20

# %%
# Totally ignored
print(len([edge for edge in totally_ignored if edge['reciprocity_dict']['summed weights']>50]))
print(len([edge for edge in totally_ignored if edge['reciprocity_dict']['summed weights']>100]))
print(len([edge for edge in totally_ignored if edge['reciprocity_dict']['summed weights']>200]))
# Out:
# 651
# 217
# 44

# %%
#Heavily Ignored / Big Media / Gossip / Paparazzi
[edge for edge in ignored if edge['reciprocity_dict']['summed weights']>200][:5]
# Out:
# [{'focus_node': 'bestof',
#   'neighbor_node': 'todayilearned',
#   'reciprocity_dict': {'reciprocity': 0.9957446808510638,
#    'summed weights': 235,
#    'n-to-m': 234,
#    'm_to_n': 1}},
#  {'focus_node': 'bestof',
#   'neighbor_node': 'explainlikeimfive',
#   'reciprocity_dict': {'reciprocity': 0.9952830188679245,
#    'summed weights': 212,
#    'n-to-m': 211,
#    'm_to_n': 1}},
#  {'focus_node': 'bestof',
#   'neighbor_node': 'worldnews',
#   'reciprocity_dict': {'reciprocity': 0.9953703703703703,
#    'summed weights': 216,
#    'n-to-m': 215,
#    'm_to_n': 1}},
#  {'focus_node': 'atletico',
#   'neighbor_node': 'soccer',
#   'reciprocity_dict': {'reciprocity': 0.9134199134199135,
#    'summed weights': 231,
#    'n-to-m': 211,
#    'm_to_n': 20}},
#  {'focus_node': 'goodshibe',
#   'neighbor_node': 'dogecoin',
#   'reciprocity_dict': {'reciprocity': 0.9739413680781759,
#    'summed weights': 307,
#    'n-to-m': 299,
#    'm_to_n': 8}}]

# %%
#Totally Ignored / Big Media / Gossip / Paparazzi
[edge for edge in totally_ignored if edge['reciprocity_dict']['summed weights']>200][:5]
# Out:
# [{'focus_node': 'bestof',
#   'neighbor_node': 'adviceanimals',
#   'reciprocity_dict': {'reciprocity': 1.0,
#    'summed weights': 217,
#    'n-to-m': 217,
#    'm_to_n': 0}},
#  {'focus_node': 'bestof',
#   'neighbor_node': 'funny',
#   'reciprocity_dict': {'reciprocity': 1.0,
#    'summed weights': 214,
#    'n-to-m': 214,
#    'm_to_n': 0}},
#  {'focus_node': 'bestof',
#   'neighbor_node': 'wtf',
#   'reciprocity_dict': {'reciprocity': 1.0,
#    'summed weights': 222,
#    'n-to-m': 222,
#    'm_to_n': 0}},
#  {'focus_node': 'bestof',
#   'neighbor_node': 'pics',
#   'reciprocity_dict': {'reciprocity': 1.0,
#    'summed weights': 222,
#    'n-to-m': 222,
#    'm_to_n': 0}},
#  {'focus_node': 'bestof',
#   'neighbor_node': 'politics',
#   'reciprocity_dict': {'reciprocity': 1.0,
#    'summed weights': 203,
#    'n-to-m': 203,
#    'm_to_n': 0}}]

# %% [markdown]
# This is beginning to look like it's all just "best_of", which makes sense, since this would aggregate things from all over but probably not be referenced back.

# %%
Counter([x['focus_node'] for x in [edge for edge in totally_ignored if edge['reciprocity_dict']['summed weights']>200]]).most_common()
# Out:
# [('circlebroke2', 7),
#  ('bestof', 6),
#  ('shitredditsays', 6),
#  ('switcharoo', 4),
#  ('shitpost', 3),
#  ('shitstatistssay', 2),
#  ('bestoftldr', 2),
#  ('fitnesscirclejerk', 1),
#  ('badphilosophy', 1),
#  ('programmingcirclejerk', 1),
#  ('edmprodcirclejerk', 1),
#  ('mushroomkingdom', 1),
#  ('bluejackets', 1),
#  ('metacanada', 1),
#  ('beercirclejerk', 1),
#  ('trendingsubreddits', 1),
#  ('bicyclingcirclejerk', 1),
#  ('evenwithcontext', 1),
#  ('titlegore', 1),
#  ('nightlypick', 1),
#  ('moronicmondayandroid', 1)]

# %%
Counter([x['focus_node'] for x in [edge for edge in ignored if edge['reciprocity_dict']['summed weights']>200]]).most_common()
# Out:
# [('bestof', 3),
#  ('subredditdrama', 2),
#  ('enoughlibertarianspam', 2),
#  ('atletico', 1),
#  ('goodshibe', 1),
#  ('shitredditsays', 1),
#  ('writingprompts', 1),
#  ('badphilosophy', 1),
#  ('japancirclejerk', 1),
#  ('drugscirclejerk', 1),
#  ('streetfighter', 1),
#  ('shitpost', 1),
#  ('runningcirclejerk', 1),
#  ('babymetal', 1),
#  ('mfacirclejerk', 1),
#  ('baseballnightlypick', 1)]
