# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Modifying the path so we can import from src directory.
import sys
import os
sys.path.append(os.path.abspath('..'))

from collections import Counter, defaultdict
from itertools import chain
import copy
import pickle
import random
import time

import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
from pyvis.network import Network

from src.example_graphs import simple_undirected_graph, simple_directed_graph
from src.UndirectedGraph import UndirectedGraph
from src.DirectedGraph import DirectedGraph
from src.DataLoader import DataLoader
from src.GraphCreator import GraphCreator, NetworkXGraphCreator

from src.io_helpers import pickle_obj, load_pickled_obj
from src.networkx_helpers import combine_graphs

from src.pyvis_helpers import visualize_random_graph, nums_to_greyscale_hex

# %%
# Random Subgraphs experiment imports
from src.random_subgraphs import randomly_sample_adjacent_nodes

# %%
ROOT_DIRECTORY = os.path.split(os.getcwd())[0]
DATA_DIRECTORY = os.path.join(ROOT_DIRECTORY, 'data')
PICKLED_DATA_DIRECTORY = os.path.join(ROOT_DIRECTORY, 'data_pickle')

EXPERIMENT_NAME = 'random_subgraphs_exp_1.0'
PICKLED_DATA_EXPERIMENTS_DIRECTORY = os.path.join(ROOT_DIRECTORY, 'data_pickle', EXPERIMENT_NAME)
EXPERIMENT_IMAGE_DIRECTORY = EXPERIMENT_NAME

# Check if image directory for this experiment exists. Create it if it doesn't.
if not os.path.isdir(os.path.join(ROOT_DIRECTORY, 'notebooks', EXPERIMENT_NAME)):
    os.mkdir(os.path.join(ROOT_DIRECTORY, 'notebooks', EXPERIMENT_NAME))
    
# Check if pickled data directory for this experiment exists. Create it if it doesn't.
if not os.path.isdir(PICKLED_DATA_EXPERIMENTS_DIRECTORY):
    os.mkdir(PICKLED_DATA_EXPERIMENTS_DIRECTORY)

# %% [markdown]
# # Ok, what if we were to start with the max-degree node (askreddit) and only take it's _x_% "most interesting" adjacent nodes, then repeat?
# We could probably define "most interesting" in a few different ways, given the metrics we already have available:
#
# 1. Max in-degree.
# 2. Max out-degree.
# 3. Max degree.
# 4. Reciprocity somewhere in the middle.
#
# ## Or, another idea—what if we just take a random _x_%? Let's try that.

# %%
G_weighted = load_pickled_obj(os.path.join(PICKLED_DATA_DIRECTORY, 'networkx_weighted_full.pickle'))

# %%
# Sample from our node
sampled_nodes, new_exclusions = randomly_sample_adjacent_nodes(G_weighted, node, divisor, exclusions)

# Update our exclusions
exclusions.update(new_exclusions)

# Add our sampled nodes to our full list
random_node_edge_pairs.extend(sampled_nodes)

# Add our new sampled nodes to our queue to sample from in the future
queue.extend([x[1] for x in sampled_nodes])

# Add the node that we just processed to our exclusion list
exclusions.add(node)

print("Iteration:", count)
print("Sampled:", len(sampled_nodes))
print("Total sampled:", len(random_node_edge_pairs))
print("Rejected triplets:", len(exclusions))
print("Queue:", len(queue))

count += 1
node = queue.pop()
# Out:
# Iteration: 18
# Sampled: 2
# Total sampled: 40
# Rejected triplets: 871
# Queue: 23

# %%
test_random_sample = nx.from_edgelist(random_node_edge_pairs, nx.DiGraph)

# %%
g = Network(notebook=True)
g.from_nx(test_random_sample)
g.show(os.path.join(EXPERIMENT_IMAGE_DIRECTORY, 'random-sample-1-smaller.html'))
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="random_subgraphs_exp_1.0/random-sample-1-smaller.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ### Color by Degree

# %%
# Copying and editing visualize_random_graph helper function from src.pyvis_helpers

graph = test_random_sample
filename = os.path.join(EXPERIMENT_IMAGE_DIRECTORY, 'random-sample-1-with-color-2.html')
g = Network(notebook=True)
#g.barnes_hut()
G_nodes = graph.nodes

# Coloring by degree -- doing a log transform since the degree of askreddit is so much larger
G_degrees = np.log([graph.degree(node) for node in G_nodes])
G_colors = nums_to_greyscale_hex(G_degrees)

for node, color in zip(G_nodes, G_colors):
    g.add_node(node, color=color)

for edge in graph.edges:
    g.add_edge(*edge)

g.show(filename)
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="random_subgraphs_exp_1.0/random-sample-1-with-color-2.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Running it again - askreddit - divisor of 10

# %%
###
###
# Full experiment.
###
###
random_node_edge_pairs = []
queue = []
exclusions = set()
starting_node = 'askreddit'
node = starting_node
divisor = 10
count = 1

while True:
    # Sample from our node
    sampled_nodes, new_exclusions = randomly_sample_adjacent_nodes(G_weighted, node, divisor, exclusions)

    # Update our exclusions
    exclusions.update(new_exclusions)

    # Add our sampled nodes to our full list
    random_node_edge_pairs.extend(sampled_nodes)

    # Add our new sampled nodes to our queue to sample from in the future
    queue.extend([x[1] for x in sampled_nodes])

    # Add the node that we just processed to our exclusion list
    exclusions.add(node)

    print("Iteration:", count)
    print("Sampled:", len(sampled_nodes))
    print("Total sampled:", len(random_node_edge_pairs))
    print("Rejected triplets:", len(exclusions))
    print("Queue:", len(queue))

    count += 1
    node = queue.pop()
# Out:
# Iteration: 1
# Sampled: 36
# Total sampled: 36
# Rejected triplets: 328
# Queue: 36
# Iteration: 2
# Sampled: 7
# Total sampled: 43
# Rejected triplets: 398
# Queue: 42
# Iteration: 3
# Sampled: 2
# Total sampled: 45
# Rejected triplets: 419
# Queue: 43
# Iteration: 4
# Sampled: 0
# Total sampled: 45
# Rejected triplets: 425
# Queue: 42
# Iteration: 5
# Sampled: 1
# Total sampled: 46
# Rejected triplets: 435
# Queue: 42
# Iteration: 6
# Sampled: 0
# Total sampled: 46
# Rejected triplets: 438
# Queue: 41
# Iteration: 7
# Sampled: 0
# Total sampled: 46
# Rejected triplets: 442
# Queue: 40
# Iteration: 8
# Sampled: 1
# Total sampled: 47
# Rejected triplets: 455
# Queue: 40
# Iteration: 9
# Sampled: 2
# Total sampled: 49
# Rejected triplets: 474
# Queue: 41
# Iteration: 10
# Sampled: 2
# Total sampled: 51
# Rejected triplets: 495
# Queue: 42
# Iteration: 11
# Sampled: 0
# Total sampled: 51
# Rejected triplets: 496
# Queue: 41
# Iteration: 12
# Sampled: 0
# Total sampled: 51
# Rejected triplets: 499
# Queue: 40
# Iteration: 13
# Sampled: 0
# Total sampled: 51
# Rejected triplets: 500
# Queue: 39
# Iteration: 14
# Sampled: 15
# Total sampled: 66
# Rejected triplets: 636
# Queue: 53
# Iteration: 15
# Sampled: 1
# Total sampled: 67
# Rejected triplets: 650
# Queue: 53
# Iteration: 16
# Sampled: 0
# Total sampled: 67
# Rejected triplets: 659
# Queue: 52
# Iteration: 17
# Sampled: 6
# Total sampled: 73
# Rejected triplets: 722
# Queue: 57
# Iteration: 18
# Sampled: 1
# Total sampled: 74
# Rejected triplets: 736
# Queue: 57
# Iteration: 19
# Sampled: 1
# Total sampled: 75
# Rejected triplets: 746
# Queue: 57
# Iteration: 20
# Sampled: 0
# Total sampled: 75
# Rejected triplets: 752
# Queue: 56
# Iteration: 21
# Sampled: 0
# Total sampled: 75
# Rejected triplets: 756
# Queue: 55
# Iteration: 22
# Sampled: 0
# Total sampled: 75
# Rejected triplets: 757
# Queue: 54
# Iteration: 23
# Sampled: 1
# Total sampled: 76
# Rejected triplets: 776
# Queue: 54
# Iteration: 24
# Sampled: 2
# Total sampled: 78
# Rejected triplets: 796
# Queue: 55
# Iteration: 25
# Sampled: 1
# Total sampled: 79
# Rejected triplets: 811
# Queue: 55
# Iteration: 26
# Sampled: 0
# Total sampled: 79
# Rejected triplets: 812
# Queue: 54
# Iteration: 27
# Sampled: 0
# Total sampled: 79
# Rejected triplets: 812
# Queue: 53
# Iteration: 28
# Sampled: 0
# Total sampled: 79
# Rejected triplets: 813
# Queue: 52
# Iteration: 29
# Sampled: 1
# Total sampled: 80
# Rejected triplets: 828
# Queue: 52
# Iteration: 30
# Sampled: 1
# Total sampled: 81
# Rejected triplets: 839
# Queue: 52
# Iteration: 31
# Sampled: 0
# Total sampled: 81
# Rejected triplets: 849
# Queue: 51
# Iteration: 32
# Sampled: 3
# Total sampled: 84
# Rejected triplets: 884
# Queue: 53
# Iteration: 33
# Sampled: 0
# Total sampled: 84
# Rejected triplets: 885
# Queue: 52
# Iteration: 34
# Sampled: 0
# Total sampled: 84
# Rejected triplets: 892
# Queue: 51
# Iteration: 35
# Sampled: 8
# Total sampled: 92
# Rejected triplets: 971
# Queue: 58
# Iteration: 36
# Sampled: 1
# Total sampled: 93
# Rejected triplets: 989
# Queue: 58
# Iteration: 37
# Sampled: 0
# Total sampled: 93
# Rejected triplets: 991
# Queue: 57
# Iteration: 38
# Sampled: 0
# Total sampled: 93
# Rejected triplets: 998
# Queue: 56
# Iteration: 39
# Sampled: 0
# Total sampled: 93
# Rejected triplets: 1006
# Queue: 55
# Iteration: 40
# Sampled: 0
# Total sampled: 93
# Rejected triplets: 1013
# Queue: 54
# Iteration: 41
# Sampled: 0
# Total sampled: 93
# Rejected triplets: 1016
# Queue: 53
# Iteration: 42
# Sampled: 1
# Total sampled: 94
# Rejected triplets: 1030
# Queue: 53
# Iteration: 43
# Sampled: 2
# Total sampled: 96
# Rejected triplets: 1057
# Queue: 54
# Iteration: 44
# Sampled: 1
# Total sampled: 97
# Rejected triplets: 1068
# Queue: 54
# Iteration: 45
# Sampled: 0
# Total sampled: 97
# Rejected triplets: 1069
# Queue: 53
# Iteration: 46
# Sampled: 0
# Total sampled: 97
# Rejected triplets: 1070
# Queue: 52
# Iteration: 47
# Sampled: 15
# Total sampled: 112
# Rejected triplets: 1206
# Queue: 66
# Iteration: 48
# Sampled: 0
# Total sampled: 112
# Rejected triplets: 1209
# Queue: 65
# Iteration: 49
# Sampled: 0
# Total sampled: 112
# Rejected triplets: 1217
# Queue: 64
# Iteration: 50
# Sampled: 0
# Total sampled: 112
# Rejected triplets: 1218
# Queue: 63
# Iteration: 51
# Sampled: 2
# Total sampled: 114
# Rejected triplets: 1237
# Queue: 64
# Iteration: 52
# Sampled: 0
# Total sampled: 114
# Rejected triplets: 1246
# Queue: 63
# Iteration: 53
# Sampled: 9
# Total sampled: 123
# Rejected triplets: 1328
# Queue: 71
# Iteration: 54
# Sampled: 0
# Total sampled: 123
# Rejected triplets: 1329
# Queue: 70
# Iteration: 55
# Sampled: 2
# Total sampled: 125
# Rejected triplets: 1348
# Queue: 71
# Iteration: 56
# Sampled: 0
# Total sampled: 125
# Rejected triplets: 1350
# Queue: 70
# Iteration: 57
# Sampled: 1
# Total sampled: 126
# Rejected triplets: 1363
# Queue: 70
# Iteration: 58
# Sampled: 1
# Total sampled: 127
# Rejected triplets: 1376
# Queue: 70
# Iteration: 59
# Sampled: 0
# Total sampled: 127
# Rejected triplets: 1378
# Queue: 69
# Iteration: 60
# Sampled: 0
# Total sampled: 127
# Rejected triplets: 1379
# Queue: 68
# Iteration: 61
# Sampled: 5
# Total sampled: 132
# Rejected triplets: 1432
# Queue: 72
# Iteration: 62
# Sampled: 0
# Total sampled: 132
# Rejected triplets: 1436
# Queue: 71
# Iteration: 63
# Sampled: 0
# Total sampled: 132
# Rejected triplets: 1437
# Queue: 70
# Iteration: 64
# Sampled: 0
# Total sampled: 132
# Rejected triplets: 1439
# Queue: 69
# Iteration: 65
# Sampled: 0
# Total sampled: 132
# Rejected triplets: 1440
# Queue: 68
# Iteration: 66
# Sampled: 0
# Total sampled: 132
# Rejected triplets: 1450
# Queue: 67
# Iteration: 67
# Sampled: 0
# Total sampled: 132
# Rejected triplets: 1453
# Queue: 66
# Iteration: 68
# Sampled: 0
# Total sampled: 132
# Rejected triplets: 1454
# Queue: 65
# Iteration: 69
# Sampled: 1
# Total sampled: 133
# Rejected triplets: 1469
# Queue: 65
# Iteration: 70
# Sampled: 0
# Total sampled: 133
# Rejected triplets: 1477
# Queue: 64
# Iteration: 71
# Sampled: 0
# Total sampled: 133
# Rejected triplets: 1478
# Queue: 63
# Iteration: 72
# Sampled: 3
# Total sampled: 136
# Rejected triplets: 1509
# Queue: 65
# Iteration: 73
# Sampled: 0
# Total sampled: 136
# Rejected triplets: 1517
# Queue: 64
# Iteration: 74
# Sampled: 0
# Total sampled: 136
# Rejected triplets: 1518
# Queue: 63
# Iteration: 75
# Sampled: 0
# Total sampled: 136
# Rejected triplets: 1519
# Queue: 62
# Iteration: 76
# Sampled: 0
# Total sampled: 136
# Rejected triplets: 1523
# Queue: 61
# Iteration: 77
# Sampled: 5
# Total sampled: 141
# Rejected triplets: 1575
# Queue: 65
# Iteration: 78
# Sampled: 0
# Total sampled: 141
# Rejected triplets: 1578
# Queue: 64
# Iteration: 79
# Sampled: 1
# Total sampled: 142
# Rejected triplets: 1595
# Queue: 64
# Iteration: 80
# Sampled: 1
# Total sampled: 143
# Rejected triplets: 1605
# Queue: 64
# Iteration: 81
# Sampled: 0
# Total sampled: 143
# Rejected triplets: 1606
# Queue: 63
# Iteration: 82
# Sampled: 0
# Total sampled: 143
# Rejected triplets: 1611
# Queue: 62
# Iteration: 83
# Sampled: 0
# Total sampled: 143
# Rejected triplets: 1615
# Queue: 61
# Iteration: 84
# Sampled: 1
# Total sampled: 144
# Rejected triplets: 1625
# Queue: 61
# Iteration: 85
# Sampled: 6
# Total sampled: 150
# Rejected triplets: 1682
# Queue: 66
# Iteration: 86
# Sampled: 0
# Total sampled: 150
# Rejected triplets: 1683
# Queue: 65
# Iteration: 87
# Sampled: 10
# Total sampled: 160
# Rejected triplets: 1782
# Queue: 74
# Iteration: 88
# Sampled: 0
# Total sampled: 160
# Rejected triplets: 1791
# Queue: 73
# Iteration: 89
# Sampled: 0
# Total sampled: 160
# Rejected triplets: 1792
# Queue: 72
# Iteration: 90
# Sampled: 2
# Total sampled: 162
# Rejected triplets: 1816
# Queue: 73
# Iteration: 91
# Sampled: 3
# Total sampled: 165
# Rejected triplets: 1846
# Queue: 75
# Iteration: 92
# Sampled: 0
# Total sampled: 165
# Rejected triplets: 1851
# Queue: 74
# Iteration: 93
# Sampled: 0
# Total sampled: 165
# Rejected triplets: 1860
# Queue: 73
# Iteration: 94
# Sampled: 0
# Total sampled: 165
# Rejected triplets: 1861
# Queue: 72
# Iteration: 95
# Sampled: 0
# Total sampled: 165
# Rejected triplets: 1862
# Queue: 71
# Iteration: 96
# Sampled: 0
# Total sampled: 165
# Rejected triplets: 1867
# Queue: 70
# Iteration: 97
# Sampled: 0
# Total sampled: 165
# Rejected triplets: 1868
# Queue: 69
# Iteration: 98
# Sampled: 0
# Total sampled: 165
# Rejected triplets: 1871
# Queue: 68
# Iteration: 99
# Sampled: 1
# Total sampled: 166
# Rejected triplets: 1885
# Queue: 68
# Iteration: 100
# Sampled: 2
# Total sampled: 168
# Rejected triplets: 1905
# Queue: 69
# Iteration: 101
# Sampled: 0
# Total sampled: 168
# Rejected triplets: 1907
# Queue: 68
# Iteration: 102
# Sampled: 0
# Total sampled: 168
# Rejected triplets: 1910
# Queue: 67
# Iteration: 103
# Sampled: 2
# Total sampled: 170
# Rejected triplets: 1929
# Queue: 68
# Iteration: 104
# Sampled: 0
# Total sampled: 170
# Rejected triplets: 1931
# Queue: 67
# Iteration: 105
# Sampled: 0
# Total sampled: 170
# Rejected triplets: 1940
# Queue: 66
# Iteration: 106
# Sampled: 0
# Total sampled: 170
# Rejected triplets: 1942
# Queue: 65
# Iteration: 107
# Sampled: 0
# Total sampled: 170
# Rejected triplets: 1944
# Queue: 64
# Iteration: 108
# Sampled: 0
# Total sampled: 170
# Rejected triplets: 1945
# Queue: 63
# Iteration: 109
# Sampled: 0
# Total sampled: 170
# Rejected triplets: 1946
# Queue: 62
# Iteration: 110
# Sampled: 0
# Total sampled: 170
# Rejected triplets: 1948
# Queue: 61
# Iteration: 111
# Sampled: 1
# Total sampled: 171
# Rejected triplets: 1962
# Queue: 61
# Iteration: 112
# Sampled: 0
# Total sampled: 171
# Rejected triplets: 1963
# Queue: 60
# Iteration: 113
# Sampled: 1
# Total sampled: 172
# Rejected triplets: 1978
# Queue: 60
# Iteration: 114
# Sampled: 1
# Total sampled: 173
# Rejected triplets: 1989
# Queue: 60
# Iteration: 115
# Sampled: 1
# Total sampled: 174
# Rejected triplets: 2003
# Queue: 60
# Iteration: 116
# Sampled: 0
# Total sampled: 174
# Rejected triplets: 2007
# Queue: 59
# Iteration: 117
# Sampled: 1
# Total sampled: 175
# Rejected triplets: 2024
# Queue: 59
# Iteration: 118
# Sampled: 1
# Total sampled: 176
# Rejected triplets: 2036
# Queue: 59
# Iteration: 119
# Sampled: 0
# Total sampled: 176
# Rejected triplets: 2037
# Queue: 58
# Iteration: 120
# Sampled: 0
# Total sampled: 176
# Rejected triplets: 2038
# Queue: 57
# Iteration: 121
# Sampled: 7
# Total sampled: 183
# Rejected triplets: 2108
# Queue: 63
# Iteration: 122
# Sampled: 0
# Total sampled: 183
# Rejected triplets: 2116
# Queue: 62
# Iteration: 123
# Sampled: 0
# Total sampled: 183
# Rejected triplets: 2117
# Queue: 61
# Iteration: 124
# Sampled: 14
# Total sampled: 197
# Rejected triplets: 2250
# Queue: 74
# Iteration: 125
# Sampled: 2
# Total sampled: 199
# Rejected triplets: 2277
# Queue: 75
# Iteration: 126
# Sampled: 3
# Total sampled: 202
# Rejected triplets: 2307
# Queue: 77
# Iteration: 127
# Sampled: 0
# Total sampled: 202
# Rejected triplets: 2316
# Queue: 76
# Iteration: 128
# Sampled: 0
# Total sampled: 202
# Rejected triplets: 2324
# Queue: 75
# Iteration: 129
# Sampled: 1
# Total sampled: 203
# Rejected triplets: 2338
# Queue: 75
# Iteration: 130
# Sampled: 0
# Total sampled: 203
# Rejected triplets: 2340
# Queue: 74
# Iteration: 131
# Sampled: 0
# Total sampled: 203
# Rejected triplets: 2347
# Queue: 73
# Iteration: 132
# Sampled: 0
# Total sampled: 203
# Rejected triplets: 2350
# Queue: 72
# Iteration: 133
# Sampled: 3
# Total sampled: 206
# Rejected triplets: 2379
# Queue: 74
# Iteration: 134
# Sampled: 0
# Total sampled: 206
# Rejected triplets: 2383
# Queue: 73
# Iteration: 135
# Sampled: 0
# Total sampled: 206
# Rejected triplets: 2388
# Queue: 72
# Iteration: 136
# Sampled: 0
# Total sampled: 206
# Rejected triplets: 2391
# Queue: 71
# Iteration: 137
# Sampled: 2
# Total sampled: 208
# Rejected triplets: 2411
# Queue: 72
# Iteration: 138
# Sampled: 1
# Total sampled: 209
# Rejected triplets: 2426
# Queue: 72
# Iteration: 139
# Sampled: 0
# Total sampled: 209
# Rejected triplets: 2429
# Queue: 71
# Iteration: 140
# Sampled: 0
# Total sampled: 209
# Rejected triplets: 2433
# Queue: 70
# Iteration: 141
# Sampled: 1
# Total sampled: 210
# Rejected triplets: 2443
# Queue: 70
# Iteration: 142
# Sampled: 0
# Total sampled: 210
# Rejected triplets: 2444
# Queue: 69
# Iteration: 143
# Sampled: 1
# Total sampled: 211
# Rejected triplets: 2458
# Queue: 69
# Iteration: 144
# Sampled: 0
# Total sampled: 211
# Rejected triplets: 2463
# Queue: 68
# Iteration: 145
# Sampled: 0
# Total sampled: 211
# Rejected triplets: 2466
# Queue: 67
# Iteration: 146
# Sampled: 3
# Total sampled: 214
# Rejected triplets: 2502
# Queue: 69
# Iteration: 147
# Sampled: 1
# Total sampled: 215
# Rejected triplets: 2517
# Queue: 69
# Iteration: 148
# Sampled: 1
# Total sampled: 216
# Rejected triplets: 2529
# Queue: 69
# Iteration: 149
# Sampled: 2
# Total sampled: 218
# Rejected triplets: 2551
# Queue: 70
# Iteration: 150
# Sampled: 0
# Total sampled: 218
# Rejected triplets: 2553
# Queue: 69
# Iteration: 151
# Sampled: 0
# Total sampled: 218
# Rejected triplets: 2554
# Queue: 68
# Iteration: 152
# Sampled: 0
# Total sampled: 218
# Rejected triplets: 2563
# Queue: 67
# Iteration: 153
# Sampled: 2
# Total sampled: 220
# Rejected triplets: 2587
# Queue: 68
# Iteration: 154
# Sampled: 0
# Total sampled: 220
# Rejected triplets: 2588
# Queue: 67
# Iteration: 155
# Sampled: 0
# Total sampled: 220
# Rejected triplets: 2590
# Queue: 66
# Iteration: 156
# Sampled: 0
# Total sampled: 220
# Rejected triplets: 2598
# Queue: 65
# Iteration: 157
# Sampled: 0
# Total sampled: 220
# Rejected triplets: 2599
# Queue: 64
# Iteration: 158
# Sampled: 0
# Total sampled: 220
# Rejected triplets: 2603
# Queue: 63
# Iteration: 159
# Sampled: 2
# Total sampled: 222
# Rejected triplets: 2629
# Queue: 64
# Iteration: 160
# Sampled: 0
# Total sampled: 222
# Rejected triplets: 2633
# Queue: 63
# Iteration: 161
# Sampled: 0
# Total sampled: 222
# Rejected triplets: 2637
# Queue: 62
# Iteration: 162
# Sampled: 0
# Total sampled: 222
# Rejected triplets: 2642
# Queue: 61
# Iteration: 163
# Sampled: 0
# Total sampled: 222
# Rejected triplets: 2648
# Queue: 60
# Iteration: 164
# Sampled: 0
# Total sampled: 222
# Rejected triplets: 2648
# Queue: 59
# Iteration: 165
# Sampled: 1
# Total sampled: 223
# Rejected triplets: 2666
# Queue: 59
# Iteration: 166
# Sampled: 2
# Total sampled: 225
# Rejected triplets: 2692
# Queue: 60
# Iteration: 167
# Sampled: 1
# Total sampled: 226
# Rejected triplets: 2704
# Queue: 60
# Iteration: 168
# Sampled: 0
# Total sampled: 226
# Rejected triplets: 2707
# Queue: 59
# Iteration: 169
# Sampled: 0
# Total sampled: 226
# Rejected triplets: 2708
# Queue: 58
# Iteration: 170
# Sampled: 0
# Total sampled: 226
# Rejected triplets: 2709
# Queue: 57
# Iteration: 171
# Sampled: 0
# Total sampled: 226
# Rejected triplets: 2712
# Queue: 56
# Iteration: 172
# Sampled: 0
# Total sampled: 226
# Rejected triplets: 2720
# Queue: 55
# Iteration: 173
# Sampled: 0
# Total sampled: 226
# Rejected triplets: 2722
# Queue: 54
# Iteration: 174
# Sampled: 4
# Total sampled: 230
# Rejected triplets: 2759
# Queue: 57
# Iteration: 175
# Sampled: 1
# Total sampled: 231
# Rejected triplets: 2770
# Queue: 57
# Iteration: 176
# Sampled: 0
# Total sampled: 231
# Rejected triplets: 2773
# Queue: 56
# Iteration: 177
# Sampled: 0
# Total sampled: 231
# Rejected triplets: 2774
# Queue: 55
# Iteration: 178
# Sampled: 13
# Total sampled: 244
# Rejected triplets: 2899
# Queue: 67
# Iteration: 179
# Sampled: 0
# Total sampled: 244
# Rejected triplets: 2907
# Queue: 66
# Iteration: 180
# Sampled: 2
# Total sampled: 246
# Rejected triplets: 2932
# Queue: 67
# Iteration: 181
# Sampled: 1
# Total sampled: 247
# Rejected triplets: 2951
# Queue: 67
# Iteration: 182
# Sampled: 0
# Total sampled: 247
# Rejected triplets: 2953
# Queue: 66
# Iteration: 183
# Sampled: 0
# Total sampled: 247
# Rejected triplets: 2955
# Queue: 65
# Iteration: 184
# Sampled: 1
# Total sampled: 248
# Rejected triplets: 2965
# Queue: 65
# Iteration: 185
# Sampled: 1
# Total sampled: 249
# Rejected triplets: 2981
# Queue: 65
# Iteration: 186
# Sampled: 0
# Total sampled: 249
# Rejected triplets: 2982
# Queue: 64
# Iteration: 187
# Sampled: 1
# Total sampled: 250
# Rejected triplets: 2997
# Queue: 64
# Iteration: 188
# Sampled: 2
# Total sampled: 252
# Rejected triplets: 3022
# Queue: 65
# Iteration: 189
# Sampled: 0
# Total sampled: 252
# Rejected triplets: 3028
# Queue: 64
# Iteration: 190
# Sampled: 0
# Total sampled: 252
# Rejected triplets: 3029
# Queue: 63
# Iteration: 191
# Sampled: 1
# Total sampled: 253
# Rejected triplets: 3042
# Queue: 63
# Iteration: 192
# Sampled: 0
# Total sampled: 253
# Rejected triplets: 3044
# Queue: 62
# Iteration: 193
# Sampled: 1
# Total sampled: 254
# Rejected triplets: 3054
# Queue: 62
# Iteration: 194
# Sampled: 0
# Total sampled: 254
# Rejected triplets: 3055
# Queue: 61
# Iteration: 195
# Sampled: 0
# Total sampled: 254
# Rejected triplets: 3056
# Queue: 60
# Iteration: 196
# Sampled: 4
# Total sampled: 258
# Rejected triplets: 3098
# Queue: 63
# Iteration: 197
# Sampled: 0
# Total sampled: 258
# Rejected triplets: 3100
# Queue: 62
# Iteration: 198
# Sampled: 0
# Total sampled: 258
# Rejected triplets: 3105
# Queue: 61
# Iteration: 199
# Sampled: 0
# Total sampled: 258
# Rejected triplets: 3106
# Queue: 60
# Iteration: 200
# Sampled: 0
# Total sampled: 258
# Rejected triplets: 3114
# Queue: 59
# Iteration: 201
# Sampled: 0
# Total sampled: 258
# Rejected triplets: 3115
# Queue: 58
# Iteration: 202
# Sampled: 1
# Total sampled: 259
# Rejected triplets: 3129
# Queue: 58
# Iteration: 203
# Sampled: 0
# Total sampled: 259
# Rejected triplets: 3131
# Queue: 57
# Iteration: 204
# Sampled: 2
# Total sampled: 261
# Rejected triplets: 3152
# Queue: 58
# Iteration: 205
# Sampled: 0
# Total sampled: 261
# Rejected triplets: 3158
# Queue: 57
# Iteration: 206
# Sampled: 0
# Total sampled: 261
# Rejected triplets: 3159
# Queue: 56
# Iteration: 207
# Sampled: 0
# Total sampled: 261
# Rejected triplets: 3162
# Queue: 55
# Iteration: 208
# Sampled: 0
# Total sampled: 261
# Rejected triplets: 3163
# Queue: 54
# Iteration: 209
# Sampled: 0
# Total sampled: 261
# Rejected triplets: 3165
# Queue: 53
# Iteration: 210
# Sampled: 0
# Total sampled: 261
# Rejected triplets: 3167
# Queue: 52
# Iteration: 211
# Sampled: 1
# Total sampled: 262
# Rejected triplets: 3178
# Queue: 52
# Iteration: 212
# Sampled: 0
# Total sampled: 262
# Rejected triplets: 3179
# Queue: 51
# Iteration: 213
# Sampled: 0
# Total sampled: 262
# Rejected triplets: 3183
# Queue: 50
# Iteration: 214
# Sampled: 0
# Total sampled: 262
# Rejected triplets: 3190
# Queue: 49
# Iteration: 215
# Sampled: 15
# Total sampled: 277
# Rejected triplets: 3332
# Queue: 63
# Iteration: 216
# Sampled: 3
# Total sampled: 280
# Rejected triplets: 3368
# Queue: 65
# Iteration: 217
# Sampled: 0
# Total sampled: 280
# Rejected triplets: 3370
# Queue: 64
# Iteration: 218
# Sampled: 0
# Total sampled: 280
# Rejected triplets: 3371
# Queue: 63
# Iteration: 219
# Sampled: 0
# Total sampled: 280
# Rejected triplets: 3372
# Queue: 62
# Iteration: 220
# Sampled: 0
# Total sampled: 280
# Rejected triplets: 3375
# Queue: 61
# Iteration: 221
# Sampled: 2
# Total sampled: 282
# Rejected triplets: 3395
# Queue: 62
# Iteration: 222
# Sampled: 1
# Total sampled: 283
# Rejected triplets: 3413
# Queue: 62
# Iteration: 223
# Sampled: 0
# Total sampled: 283
# Rejected triplets: 3414
# Queue: 61
# Iteration: 224
# Sampled: 0
# Total sampled: 283
# Rejected triplets: 3415
# Queue: 60
# Iteration: 225
# Sampled: 0
# Total sampled: 283
# Rejected triplets: 3418
# Queue: 59
# Iteration: 226
# Sampled: 0
# Total sampled: 283
# Rejected triplets: 3421
# Queue: 58
# Iteration: 227
# Sampled: 1
# Total sampled: 284
# Rejected triplets: 3434
# Queue: 58
# Iteration: 228
# Sampled: 4
# Total sampled: 288
# Rejected triplets: 3476
# Queue: 61
# Iteration: 229
# Sampled: 0
# Total sampled: 288
# Rejected triplets: 3480
# Queue: 60
# Iteration: 230
# Sampled: 0
# Total sampled: 288
# Rejected triplets: 3481
# Queue: 59
# Iteration: 231
# Sampled: 1
# Total sampled: 289
# Rejected triplets: 3493
# Queue: 59
# Iteration: 232
# Sampled: 1
# Total sampled: 290
# Rejected triplets: 3503
# Queue: 59
# Iteration: 233
# Sampled: 0
# Total sampled: 290
# Rejected triplets: 3504
# Queue: 58
# Iteration: 234
# Sampled: 0
# Total sampled: 290
# Rejected triplets: 3509
# Queue: 57
# Iteration: 235
# Sampled: 0
# Total sampled: 290
# Rejected triplets: 3510
# Queue: 56
# Iteration: 236
# Sampled: 0
# Total sampled: 290
# Rejected triplets: 3511
# Queue: 55
# Iteration: 237
# Sampled: 0
# Total sampled: 290
# Rejected triplets: 3514
# Queue: 54
# Iteration: 238
# Sampled: 1
# Total sampled: 291
# Rejected triplets: 3530
# Queue: 54
# Iteration: 239
# Sampled: 0
# Total sampled: 291
# Rejected triplets: 3533
# Queue: 53
# Iteration: 240
# Sampled: 1
# Total sampled: 292
# Rejected triplets: 3545
# Queue: 53
# Iteration: 241
# Sampled: 0
# Total sampled: 292
# Rejected triplets: 3546
# Queue: 52
# Iteration: 242
# Sampled: 0
# Total sampled: 292
# Rejected triplets: 3548
# Queue: 51
# Iteration: 243
# Sampled: 0
# Total sampled: 292
# Rejected triplets: 3549
# Queue: 50
# Iteration: 244
# Sampled: 0
# Total sampled: 292
# Rejected triplets: 3549
# Queue: 49
# Iteration: 245
# Sampled: 0
# Total sampled: 292
# Rejected triplets: 3555
# Queue: 48
# Iteration: 246
# Sampled: 0
# Total sampled: 292
# Rejected triplets: 3556
# Queue: 47
# Iteration: 247
# Sampled: 2
# Total sampled: 294
# Rejected triplets: 3577
# Queue: 48
# Iteration: 248
# Sampled: 0
# Total sampled: 294
# Rejected triplets: 3581
# Queue: 47
# Iteration: 249
# Sampled: 0
# Total sampled: 294
# Rejected triplets: 3582
# Queue: 46
# Iteration: 250
# Sampled: 0
# Total sampled: 294
# Rejected triplets: 3584
# Queue: 45
# Iteration: 251
# Sampled: 0
# Total sampled: 294
# Rejected triplets: 3585
# Queue: 44
# Iteration: 252
# Sampled: 2
# Total sampled: 296
# Rejected triplets: 3609
# Queue: 45
# Iteration: 253
# Sampled: 0
# Total sampled: 296
# Rejected triplets: 3610
# Queue: 44
# Iteration: 254
# Sampled: 0
# Total sampled: 296
# Rejected triplets: 3611
# Queue: 43
# Iteration: 255
# Sampled: 0
# Total sampled: 296
# Rejected triplets: 3618
# Queue: 42
# Iteration: 256
# Sampled: 1
# Total sampled: 297
# Rejected triplets: 3630
# Queue: 42
# Iteration: 257
# Sampled: 0
# Total sampled: 297
# Rejected triplets: 3631
# Queue: 41
# Iteration: 258
# Sampled: 0
# Total sampled: 297
# Rejected triplets: 3632
# Queue: 40
# Iteration: 259
# Sampled: 1
# Total sampled: 298
# Rejected triplets: 3647
# Queue: 40
# Iteration: 260
# Sampled: 2
# Total sampled: 300
# Rejected triplets: 3666
# Queue: 41
# Iteration: 261
# Sampled: 1
# Total sampled: 301
# Rejected triplets: 3684
# Queue: 41
# Iteration: 262
# Sampled: 0
# Total sampled: 301
# Rejected triplets: 3689
# Queue: 40
# Iteration: 263
# Sampled: 2
# Total sampled: 303
# Rejected triplets: 3716
# Queue: 41
# Iteration: 264
# Sampled: 0
# Total sampled: 303
# Rejected triplets: 3718
# Queue: 40
# Iteration: 265
# Sampled: 0
# Total sampled: 303
# Rejected triplets: 3720
# Queue: 39
# Iteration: 266
# Sampled: 13
# Total sampled: 316
# Rejected triplets: 3842
# Queue: 51
# Iteration: 267
# Sampled: 0
# Total sampled: 316
# Rejected triplets: 3846
# Queue: 50
# Iteration: 268
# Sampled: 0
# Total sampled: 316
# Rejected triplets: 3851
# Queue: 49
# Iteration: 269
# Sampled: 0
# Total sampled: 316
# Rejected triplets: 3854
# Queue: 48
# Iteration: 270
# Sampled: 0
# Total sampled: 316
# Rejected triplets: 3855
# Queue: 47
# Iteration: 271
# Sampled: 0
# Total sampled: 316
# Rejected triplets: 3856
# Queue: 46
# Iteration: 272
# Sampled: 1
# Total sampled: 317
# Rejected triplets: 3866
# Queue: 46
# Iteration: 273
# Sampled: 0
# Total sampled: 317
# Rejected triplets: 3867
# Queue: 45
# Iteration: 274
# Sampled: 1
# Total sampled: 318
# Rejected triplets: 3877
# Queue: 45
# Iteration: 275
# Sampled: 0
# Total sampled: 318
# Rejected triplets: 3879
# Queue: 44
# Iteration: 276
# Sampled: 0
# Total sampled: 318
# Rejected triplets: 3881
# Queue: 43
# Iteration: 277
# Sampled: 0
# Total sampled: 318
# Rejected triplets: 3884
# Queue: 42
# Iteration: 278
# Sampled: 1
# Total sampled: 319
# Rejected triplets: 3898
# Queue: 42
# Iteration: 279
# Sampled: 5
# Total sampled: 324
# Rejected triplets: 3944
# Queue: 46
# Iteration: 280
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3950
# Queue: 45
# Iteration: 281
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3951
# Queue: 44
# Iteration: 282
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3954
# Queue: 43
# Iteration: 283
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3956
# Queue: 42
# Iteration: 284
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3957
# Queue: 41
# Iteration: 285
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3959
# Queue: 40
# Iteration: 286
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3969
# Queue: 39
# Iteration: 287
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3971
# Queue: 38
# Iteration: 288
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3972
# Queue: 37
# Iteration: 289
# Sampled: 0
# Total sampled: 324
# Rejected triplets: 3974
# Queue: 36
# Iteration: 290
# Sampled: 1
# Total sampled: 325
# Rejected triplets: 3986
# Queue: 36
# Iteration: 291
# Sampled: 0
# Total sampled: 325
# Rejected triplets: 3988
# Queue: 35
# Iteration: 292
# Sampled: 8
# Total sampled: 333
# Rejected triplets: 4061
# Queue: 42
# Iteration: 293
# Sampled: 1
# Total sampled: 334
# Rejected triplets: 4077
# Queue: 42
# Iteration: 294
# Sampled: 1
# Total sampled: 335
# Rejected triplets: 4089
# Queue: 42
# Iteration: 295
# Sampled: 0
# Total sampled: 335
# Rejected triplets: 4090
# Queue: 41
# Iteration: 296
# Sampled: 0
# Total sampled: 335
# Rejected triplets: 4091
# Queue: 40
# Iteration: 297
# Sampled: 0
# Total sampled: 335
# Rejected triplets: 4092
# Queue: 39
# Iteration: 298
# Sampled: 0
# Total sampled: 335
# Rejected triplets: 4094
# Queue: 38
# Iteration: 299
# Sampled: 0
# Total sampled: 335
# Rejected triplets: 4095
# Queue: 37
# Iteration: 300
# Sampled: 0
# Total sampled: 335
# Rejected triplets: 4096
# Queue: 36
# Iteration: 301
# Sampled: 0
# Total sampled: 335
# Rejected triplets: 4099
# Queue: 35
# Iteration: 302
# Sampled: 0
# Total sampled: 335
# Rejected triplets: 4100
# Queue: 34
# Iteration: 303
# Sampled: 1
# Total sampled: 336
# Rejected triplets: 4109
# Queue: 34
# Iteration: 304
# Sampled: 0
# Total sampled: 336
# Rejected triplets: 4116
# Queue: 33
# Iteration: 305
# Sampled: 1
# Total sampled: 337
# Rejected triplets: 4134
# Queue: 33
# Iteration: 306
# Sampled: 0
# Total sampled: 337
# Rejected triplets: 4138
# Queue: 32
# Iteration: 307
# Sampled: 3
# Total sampled: 340
# Rejected triplets: 4169
# Queue: 34
# Iteration: 308
# Sampled: 0
# Total sampled: 340
# Rejected triplets: 4178
# Queue: 33
# Iteration: 309
# Sampled: 0
# Total sampled: 340
# Rejected triplets: 4181
# Queue: 32
# Iteration: 310
# Sampled: 0
# Total sampled: 340
# Rejected triplets: 4181
# Queue: 31
# Iteration: 311
# Sampled: 1
# Total sampled: 341
# Rejected triplets: 4191
# Queue: 31
# Iteration: 312
# Sampled: 0
# Total sampled: 341
# Rejected triplets: 4196
# Queue: 30
# Iteration: 313
# Sampled: 2
# Total sampled: 343
# Rejected triplets: 4217
# Queue: 31
# Iteration: 314
# Sampled: 0
# Total sampled: 343
# Rejected triplets: 4218
# Queue: 30
# Iteration: 315
# Sampled: 0
# Total sampled: 343
# Rejected triplets: 4219
# Queue: 29
# Iteration: 316
# Sampled: 10
# Total sampled: 353
# Rejected triplets: 4318
# Queue: 38
# Iteration: 317
# Sampled: 0
# Total sampled: 353
# Rejected triplets: 4319
# Queue: 37
# Iteration: 318
# Sampled: 0
# Total sampled: 353
# Rejected triplets: 4322
# Queue: 36
# Iteration: 319
# Sampled: 1
# Total sampled: 354
# Rejected triplets: 4334
# Queue: 36
# Iteration: 320
# Sampled: 0
# Total sampled: 354
# Rejected triplets: 4335
# Queue: 35
# Iteration: 321
# Sampled: 0
# Total sampled: 354
# Rejected triplets: 4336
# Queue: 34
# Iteration: 322
# Sampled: 0
# Total sampled: 354
# Rejected triplets: 4337
# Queue: 33
# Iteration: 323
# Sampled: 1
# Total sampled: 355
# Rejected triplets: 4350
# Queue: 33
# Iteration: 324
# Sampled: 0
# Total sampled: 355
# Rejected triplets: 4351
# Queue: 32
# Iteration: 325
# Sampled: 0
# Total sampled: 355
# Rejected triplets: 4357
# Queue: 31
# Iteration: 326
# Sampled: 0
# Total sampled: 355
# Rejected triplets: 4358
# Queue: 30
# Iteration: 327
# Sampled: 0
# Total sampled: 355
# Rejected triplets: 4359
# Queue: 29
# Iteration: 328
# Sampled: 0
# Total sampled: 355
# Rejected triplets: 4360
# Queue: 28
# Iteration: 329
# Sampled: 0
# Total sampled: 355
# Rejected triplets: 4362
# Queue: 27
# Iteration: 330
# Sampled: 1
# Total sampled: 356
# Rejected triplets: 4380
# Queue: 27
# Iteration: 331
# Sampled: 0
# Total sampled: 356
# Rejected triplets: 4387
# Queue: 26
# Iteration: 332
# Sampled: 0
# Total sampled: 356
# Rejected triplets: 4388
# Queue: 25
# Iteration: 333
# Sampled: 3
# Total sampled: 359
# Rejected triplets: 4417
# Queue: 27
# Iteration: 334
# Sampled: 0
# Total sampled: 359
# Rejected triplets: 4422
# Queue: 26
# Iteration: 335
# Sampled: 1
# Total sampled: 360
# Rejected triplets: 4434
# Queue: 26
# Iteration: 336
# Sampled: 0
# Total sampled: 360
# Rejected triplets: 4442
# Queue: 25
# Iteration: 337
# Sampled: 0
# Total sampled: 360
# Rejected triplets: 4443
# Queue: 24
# Iteration: 338
# Sampled: 0
# Total sampled: 360
# Rejected triplets: 4444
# Queue: 23
# Iteration: 339
# Sampled: 5
# Total sampled: 365
# Rejected triplets: 4497
# Queue: 27
# Iteration: 340
# Sampled: 0
# Total sampled: 365
# Rejected triplets: 4498
# Queue: 26
# Iteration: 341
# Sampled: 0
# Total sampled: 365
# Rejected triplets: 4501
# Queue: 25
# Iteration: 342
# Sampled: 0
# Total sampled: 365
# Rejected triplets: 4502
# Queue: 24
# Iteration: 343
# Sampled: 13
# Total sampled: 378
# Rejected triplets: 4628
# Queue: 36
# Iteration: 344
# Sampled: 2
# Total sampled: 380
# Rejected triplets: 4656
# Queue: 37
# Iteration: 345
# Sampled: 0
# Total sampled: 380
# Rejected triplets: 4658
# Queue: 36
# Iteration: 346
# Sampled: 0
# Total sampled: 380
# Rejected triplets: 4663
# Queue: 35
# Iteration: 347
# Sampled: 0
# Total sampled: 380
# Rejected triplets: 4667
# Queue: 34
# Iteration: 348
# Sampled: 0
# Total sampled: 380
# Rejected triplets: 4668
# Queue: 33
# Iteration: 349
# Sampled: 0
# Total sampled: 380
# Rejected triplets: 4672
# Queue: 32
# Iteration: 350
# Sampled: 0
# Total sampled: 380
# Rejected triplets: 4680
# Queue: 31
# Iteration: 351
# Sampled: 0
# Total sampled: 380
# Rejected triplets: 4683
# Queue: 30
# Iteration: 352
# Sampled: 8
# Total sampled: 388
# Rejected triplets: 4763
# Queue: 37
# Iteration: 353
# Sampled: 0
# Total sampled: 388
# Rejected triplets: 4770
# Queue: 36
# Iteration: 354
# Sampled: 0
# Total sampled: 388
# Rejected triplets: 4771
# Queue: 35
# Iteration: 355
# Sampled: 0
# Total sampled: 388
# Rejected triplets: 4772
# Queue: 34
# Iteration: 356
# Sampled: 1
# Total sampled: 389
# Rejected triplets: 4784
# Queue: 34
# Iteration: 357
# Sampled: 0
# Total sampled: 389
# Rejected triplets: 4793
# Queue: 33
# Iteration: 358
# Sampled: 0
# Total sampled: 389
# Rejected triplets: 4794
# Queue: 32
# Iteration: 359
# Sampled: 0
# Total sampled: 389
# Rejected triplets: 4795
# Queue: 31
# Iteration: 360
# Sampled: 1
# Total sampled: 390
# Rejected triplets: 4811
# Queue: 31
# Iteration: 361
# Sampled: 0
# Total sampled: 390
# Rejected triplets: 4812
# Queue: 30
# Iteration: 362
# Sampled: 0
# Total sampled: 390
# Rejected triplets: 4813
# Queue: 29
# Iteration: 363
# Sampled: 0
# Total sampled: 390
# Rejected triplets: 4817
# Queue: 28
# Iteration: 364
# Sampled: 0
# Total sampled: 390
# Rejected triplets: 4821
# Queue: 27
# Iteration: 365
# Sampled: 0
# Total sampled: 390
# Rejected triplets: 4827
# Queue: 26
# Iteration: 366
# Sampled: 0
# Total sampled: 390
# Rejected triplets: 4828
# Queue: 25
# Iteration: 367
# Sampled: 2
# Total sampled: 392
# Rejected triplets: 4847
# Queue: 26
# Iteration: 368
# Sampled: 0
# Total sampled: 392
# Rejected triplets: 4854
# Queue: 25
# Iteration: 369
# Sampled: 0
# Total sampled: 392
# Rejected triplets: 4856
# Queue: 24
# Iteration: 370
# Sampled: 106
# Total sampled: 498
# Rejected triplets: 5812
# Queue: 129
# Iteration: 371
# Sampled: 0
# Total sampled: 498
# Rejected triplets: 5813
# Queue: 128
# Iteration: 372
# Sampled: 0
# Total sampled: 498
# Rejected triplets: 5815
# Queue: 127
# Iteration: 373
# Sampled: 0
# Total sampled: 498
# Rejected triplets: 5816
# Queue: 126
# Iteration: 374
# Sampled: 0
# Total sampled: 498
# Rejected triplets: 5820
# Queue: 125
# Iteration: 375
# Sampled: 0
# Total sampled: 498
# Rejected triplets: 5821
# Queue: 124
# Iteration: 376
# Sampled: 0
# Total sampled: 498
# Rejected triplets: 5823
# Queue: 123
# Iteration: 377
# Sampled: 2
# Total sampled: 500
# Rejected triplets: 5850
# Queue: 124
# Iteration: 378
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5859
# Queue: 123
# Iteration: 379
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5867
# Queue: 122
# Iteration: 380
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5870
# Queue: 121
# Iteration: 381
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5871
# Queue: 120
# Iteration: 382
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5874
# Queue: 119
# Iteration: 383
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5877
# Queue: 118
# Iteration: 384
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5879
# Queue: 117
# Iteration: 385
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5883
# Queue: 116
# Iteration: 386
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5884
# Queue: 115
# Iteration: 387
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5887
# Queue: 114
# Iteration: 388
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5888
# Queue: 113
# Iteration: 389
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5889
# Queue: 112
# Iteration: 390
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5890
# Queue: 111
# Iteration: 391
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5896
# Queue: 110
# Iteration: 392
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5900
# Queue: 109
# Iteration: 393
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5902
# Queue: 108
# Iteration: 394
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5904
# Queue: 107
# Iteration: 395
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5905
# Queue: 106
# Iteration: 396
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5909
# Queue: 105
# Iteration: 397
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5911
# Queue: 104
# Iteration: 398
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5921
# Queue: 103
# Iteration: 399
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5924
# Queue: 102
# Iteration: 400
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5927
# Queue: 101
# Iteration: 401
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5930
# Queue: 100
# Iteration: 402
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5933
# Queue: 99
# Iteration: 403
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5934
# Queue: 98
# Iteration: 404
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5935
# Queue: 97
# Iteration: 405
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5937
# Queue: 96
# Iteration: 406
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5938
# Queue: 95
# Iteration: 407
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5941
# Queue: 94
# Iteration: 408
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5945
# Queue: 93
# Iteration: 409
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5951
# Queue: 92
# Iteration: 410
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5954
# Queue: 91
# Iteration: 411
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5955
# Queue: 90
# Iteration: 412
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5958
# Queue: 89
# Iteration: 413
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5966
# Queue: 88
# Iteration: 414
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5967
# Queue: 87
# Iteration: 415
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5970
# Queue: 86
# Iteration: 416
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5971
# Queue: 85
# Iteration: 417
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5972
# Queue: 84
# Iteration: 418
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5974
# Queue: 83
# Iteration: 419
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5981
# Queue: 82
# Iteration: 420
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5983
# Queue: 81
# Iteration: 421
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5986
# Queue: 80
# Iteration: 422
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5987
# Queue: 79
# Iteration: 423
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5988
# Queue: 78
# Iteration: 424
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5989
# Queue: 77
# Iteration: 425
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5993
# Queue: 76
# Iteration: 426
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5994
# Queue: 75
# Iteration: 427
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5995
# Queue: 74
# Iteration: 428
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 5996
# Queue: 73
# Iteration: 429
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 6001
# Queue: 72
# Iteration: 430
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 6002
# Queue: 71
# Iteration: 431
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 6008
# Queue: 70
# Iteration: 432
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 6009
# Queue: 69
# Iteration: 433
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 6010
# Queue: 68
# Iteration: 434
# Sampled: 0
# Total sampled: 500
# Rejected triplets: 6016
# Queue: 67
# Iteration: 435
# Sampled: 1
# Total sampled: 501
# Rejected triplets: 6026
# Queue: 67
# Iteration: 436
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6027
# Queue: 66
# Iteration: 437
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6031
# Queue: 65
# Iteration: 438
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6032
# Queue: 64
# Iteration: 439
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6037
# Queue: 63
# Iteration: 440
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6039
# Queue: 62
# Iteration: 441
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6041
# Queue: 61
# Iteration: 442
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6044
# Queue: 60
# Iteration: 443
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6045
# Queue: 59
# Iteration: 444
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6048
# Queue: 58
# Iteration: 445
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6049
# Queue: 57
# Iteration: 446
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6050
# Queue: 56
# Iteration: 447
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6054
# Queue: 55
# Iteration: 448
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6055
# Queue: 54
# Iteration: 449
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6058
# Queue: 53
# Iteration: 450
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6062
# Queue: 52
# Iteration: 451
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6065
# Queue: 51
# Iteration: 452
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6066
# Queue: 50
# Iteration: 453
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6072
# Queue: 49
# Iteration: 454
# Sampled: 0
# Total sampled: 501
# Rejected triplets: 6073
# Queue: 48
# Iteration: 455
# Sampled: 1
# Total sampled: 502
# Rejected triplets: 6091
# Queue: 48
# Iteration: 456
# Sampled: 3
# Total sampled: 505
# Rejected triplets: 6126
# Queue: 50
# Iteration: 457
# Sampled: 0
# Total sampled: 505
# Rejected triplets: 6127
# Queue: 49
# Iteration: 458
# Sampled: 1
# Total sampled: 506
# Rejected triplets: 6137
# Queue: 49
# Iteration: 459
# Sampled: 1
# Total sampled: 507
# Rejected triplets: 6151
# Queue: 49
# Iteration: 460
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6153
# Queue: 48
# Iteration: 461
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6155
# Queue: 47
# Iteration: 462
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6157
# Queue: 46
# Iteration: 463
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6161
# Queue: 45
# Iteration: 464
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6165
# Queue: 44
# Iteration: 465
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6166
# Queue: 43
# Iteration: 466
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6169
# Queue: 42
# Iteration: 467
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6173
# Queue: 41
# Iteration: 468
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6175
# Queue: 40
# Iteration: 469
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6176
# Queue: 39
# Iteration: 470
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6180
# Queue: 38
# Iteration: 471
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6181
# Queue: 37
# Iteration: 472
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6182
# Queue: 36
# Iteration: 473
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6183
# Queue: 35
# Iteration: 474
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6185
# Queue: 34
# Iteration: 475
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6187
# Queue: 33
# Iteration: 476
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6190
# Queue: 32
# Iteration: 477
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6196
# Queue: 31
# Iteration: 478
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6202
# Queue: 30
# Iteration: 479
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6206
# Queue: 29
# Iteration: 480
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6207
# Queue: 28
# Iteration: 481
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6215
# Queue: 27
# Iteration: 482
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6217
# Queue: 26
# Iteration: 483
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6225
# Queue: 25
# Iteration: 484
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6228
# Queue: 24
# Iteration: 485
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6229
# Queue: 23
# Iteration: 486
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6236
# Queue: 22
# Iteration: 487
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6244
# Queue: 21
# Iteration: 488
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6245
# Queue: 20
# Iteration: 489
# Sampled: 0
# Total sampled: 507
# Rejected triplets: 6245
# Queue: 19
# Iteration: 490
# Sampled: 1
# Total sampled: 508
# Rejected triplets: 6257
# Queue: 19
# Iteration: 491
# Sampled: 0
# Total sampled: 508
# Rejected triplets: 6259
# Queue: 18
# Iteration: 492
# Sampled: 1
# Total sampled: 509
# Rejected triplets: 6275
# Queue: 18
# Iteration: 493
# Sampled: 0
# Total sampled: 509
# Rejected triplets: 6278
# Queue: 17
# Iteration: 494
# Sampled: 1
# Total sampled: 510
# Rejected triplets: 6291
# Queue: 17
# Iteration: 495
# Sampled: 0
# Total sampled: 510
# Rejected triplets: 6292
# Queue: 16
# Iteration: 496
# Sampled: 3
# Total sampled: 513
# Rejected triplets: 6321
# Queue: 18
# Iteration: 497
# Sampled: 0
# Total sampled: 513
# Rejected triplets: 6322
# Queue: 17
# Iteration: 498
# Sampled: 0
# Total sampled: 513
# Rejected triplets: 6323
# Queue: 16
# Iteration: 499
# Sampled: 0
# Total sampled: 513
# Rejected triplets: 6324
# Queue: 15
# Iteration: 500
# Sampled: 0
# Total sampled: 513
# Rejected triplets: 6325
# Queue: 14
# Iteration: 501
# Sampled: 0
# Total sampled: 513
# Rejected triplets: 6334
# Queue: 13
# Iteration: 502
# Sampled: 4
# Total sampled: 517
# Rejected triplets: 6370
# Queue: 16
# Iteration: 503
# Sampled: 0
# Total sampled: 517
# Rejected triplets: 6375
# Queue: 15
# Iteration: 504
# Sampled: 0
# Total sampled: 517
# Rejected triplets: 6376
# Queue: 14
# Iteration: 505
# Sampled: 0
# Total sampled: 517
# Rejected triplets: 6377
# Queue: 13
# Iteration: 506
# Sampled: 0
# Total sampled: 517
# Rejected triplets: 6378
# Queue: 12
# Iteration: 507
# Sampled: 3
# Total sampled: 520
# Rejected triplets: 6407
# Queue: 14
# Iteration: 508
# Sampled: 0
# Total sampled: 520
# Rejected triplets: 6409
# Queue: 13
# Iteration: 509
# Sampled: 0
# Total sampled: 520
# Rejected triplets: 6414
# Queue: 12
# Iteration: 510
# Sampled: 0
# Total sampled: 520
# Rejected triplets: 6418
# Queue: 11
# Iteration: 511
# Sampled: 1
# Total sampled: 521
# Rejected triplets: 6427
# Queue: 11
# Iteration: 512
# Sampled: 0
# Total sampled: 521
# Rejected triplets: 6428
# Queue: 10
# Iteration: 513
# Sampled: 0
# Total sampled: 521
# Rejected triplets: 6428
# Queue: 9
# Iteration: 514
# Sampled: 3
# Total sampled: 524
# Rejected triplets: 6462
# Queue: 11
# Iteration: 515
# Sampled: 0
# Total sampled: 524
# Rejected triplets: 6463
# Queue: 10
# Iteration: 516
# Sampled: 0
# Total sampled: 524
# Rejected triplets: 6464
# Queue: 9
# Iteration: 517
# Sampled: 0
# Total sampled: 524
# Rejected triplets: 6465
# Queue: 8
# Iteration: 518
# Sampled: 0
# Total sampled: 524
# Rejected triplets: 6468
# Queue: 7
# Iteration: 519
# Sampled: 2
# Total sampled: 526
# Rejected triplets: 6494
# Queue: 8
# Iteration: 520
# Sampled: 0
# Total sampled: 526
# Rejected triplets: 6504
# Queue: 7
# Iteration: 521
# Sampled: 0
# Total sampled: 526
# Rejected triplets: 6505
# Queue: 6
# Iteration: 522
# Sampled: 0
# Total sampled: 526
# Rejected triplets: 6507
# Queue: 5
# Iteration: 523
# Sampled: 0
# Total sampled: 526
# Rejected triplets: 6515
# Queue: 4
# Iteration: 524
# Sampled: 0
# Total sampled: 526
# Rejected triplets: 6522
# Queue: 3
# Iteration: 525
# Sampled: 1
# Total sampled: 527
# Rejected triplets: 6537
# Queue: 3
# Iteration: 526
# Sampled: 0
# Total sampled: 527
# Rejected triplets: 6541
# Queue: 2
# Iteration: 527
# Sampled: 1
# Total sampled: 528
# Rejected triplets: 6556
# Queue: 2
# Iteration: 528
# Sampled: 0
# Total sampled: 528
# Rejected triplets: 6559
# Queue: 1
# Iteration: 529
# Sampled: 1
# Total sampled: 529
# Rejected triplets: 6576
# Queue: 1
# Iteration: 530
# Sampled: 0
# Total sampled: 529
# Rejected triplets: 6577
# Queue: 0
# -------------------------------------------------------------------------
# IndexError                              Traceback (most recent call last)
# <ipython-input-57-88c1eea9ed5f> in <module>
#      35
#      36     count += 1
# ---> 37     node = queue.pop()
#
# IndexError: pop from empty list

# %%
graph_to_plot = nx.from_edgelist(random_node_edge_pairs, nx.DiGraph)

# Copying and editing visualize_random_graph helper function from src.pyvis_helpers
graph = graph_to_plot
filename = os.path.join(EXPERIMENT_IMAGE_DIRECTORY, '{}-{}.html'.format(starting_node, divisor))
g = Network(notebook=True)
#g.barnes_hut()
G_nodes = graph.nodes

# Coloring by degree -- doing a log transform since the degree of askreddit is so much larger
G_degrees = np.log([graph.degree(node) for node in G_nodes])
G_colors = nums_to_greyscale_hex(G_degrees)

for node, color in zip(G_nodes, G_colors):
    g.add_node(node, color=color)

for edge in graph.edges:
    g.add_edge(*edge)

g.show(filename)
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="random_subgraphs_exp_1.0/askreddit-10.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pickle_obj(graph_to_plot, os.path.join(PICKLED_DATA_EXPERIMENTS_DIRECTORY, "graph-{}-{}.pickle".format(starting_node, divisor)))

# %% [markdown]
# ## Running it again - vegan - divisor of 10

# %%
###
###
# Full experiment.
###
###
random_node_edge_pairs = []
queue = []
exclusions = set()
starting_node = 'vegan'
node = starting_node
divisor = 10
count = 1
log_list = []

while True:
    # Sample from our node
    sampled_nodes, new_exclusions = randomly_sample_adjacent_nodes(G_weighted, node, divisor, exclusions)

    # Update our exclusions
    exclusions.update(new_exclusions)

    # Add our sampled nodes to our full list
    random_node_edge_pairs.extend(sampled_nodes)

    # Add our new sampled nodes to our queue to sample from in the future
    queue.extend([x[1] for x in sampled_nodes])

    # Add the node that we just processed to our exclusion list
    exclusions.add(node)

    #print("Iteration:", count)
    #print("Sampled:", len(sampled_nodes))
    #print("Total sampled:", len(random_node_edge_pairs))
    #print("Rejected triplets:", len(exclusions))
    #print("Queue:", len(queue))
    
    log_list.append({
        "Iteration": count,
        "Sampled": len(sampled_nodes),
        "Total sampled": len(random_node_edge_pairs),
        "Rejected triplets": len(exclusions),
        "Queue": len(queue)
    })

    count += 1
    try:
        node = queue.pop()
    except:
        print("Finished after {} iterations.".format(count))
        break
# Out:
# Finished after 429 iterations.

# %%
print(random_node_edge_pairs[:3])
print(len(queue))
print(len(exclusions))
print(count)
# Out:
# [('vegan', 'starbucks', {'weight': 1}), ('vegan', 'plantbaseddiet', {'weight': 1}), ('vegan', 'veganpizza', {'weight': 2})]
# 0
# 5306
# 429

# %%
graph_to_plot = nx.from_edgelist(random_node_edge_pairs, nx.DiGraph)

# Pickling in case we want to bring up this exact dataset again.
pickle_obj(graph_to_plot, os.path.join(PICKLED_DATA_EXPERIMENTS_DIRECTORY, "graph-{}-{}.pickle".format(starting_node, divisor)))

# Copying and editing visualize_random_graph helper function from src.pyvis_helpers
graph = graph_to_plot
filename = os.path.join(EXPERIMENT_IMAGE_DIRECTORY, '{}-{}.html'.format(starting_node, divisor))
g = Network(notebook=True)
#g.barnes_hut()
G_nodes = graph.nodes

# Coloring by degree -- doing a log transform since the degree of askreddit is so much larger
G_degrees = np.log([graph.degree(node) for node in G_nodes])
G_colors = nums_to_greyscale_hex(G_degrees)

for node, color in zip(G_nodes, G_colors):
    g.add_node(node, color=color)

for edge in graph.edges:
    g.add_edge(*edge)

g.show(filename)

# %% [markdown]
# ## Running it again, but this time alter it slightly to get the whole graph - askreddit - divisor of 20

# %%
def randomly_sample_adjacent_nodes_full_graph_tweak(graph, node, divisor, exclusions):
    # Adjacent nodes to select from, excluding nodes in our exclusion list
    adjacent_nodes = [n for n in list(graph[node]) if n not in exclusions]
    
    # Randomly select some of those nodes
    random_nodes = random.sample(adjacent_nodes, len(adjacent_nodes) // divisor)
    if len(adjacent_nodes) > 0 and len(random_nodes) == 0:
        random_nodes = random.sample(adjacent_nodes, 1)
    
    # In the future, we also want to exclude the nodes we didn't choose
    new_exclusions = set(adjacent_nodes) - set(random_nodes)
    
    # Now, we want to get the full edge triplets for our chosen nodes
    # so we can create a new graph from them in the future
    node_edge_weight_triplets = [
        (node, adj_node, graph.get_edge_data(node, adj_node))
        for adj_node in random_nodes
    ]
    
    return node_edge_weight_triplets, new_exclusions

# %%
###
###
# Full experiment.
###
###
random_node_edge_pairs = []
queue = []
exclusions = set()
starting_node = 'askreddit'
node = starting_node
divisor = 10
count = 1
log_list = []

while True:
    # Sample from our node
    sampled_nodes, new_exclusions = randomly_sample_adjacent_nodes_full_graph_tweak(
        G_weighted,
        node,
        divisor,
        exclusions
    )

    # Update our exclusions
    exclusions.update(new_exclusions)

    # Add our sampled nodes to our full list
    random_node_edge_pairs.extend(sampled_nodes)

    # Add our new sampled nodes to our queue to sample from in the future
    queue.extend([x[1] for x in sampled_nodes])

    # Add the node that we just processed to our exclusion list
    exclusions.add(node)

    #print("Iteration:", count)
    #print("Sampled:", len(sampled_nodes))
    #print("Total sampled:", len(random_node_edge_pairs))
    #print("Rejected triplets:", len(exclusions))
    #print("Queue:", len(queue))
    
    log_list.append({
        "Iteration": count,
        "Sampled": len(sampled_nodes),
        "Total sampled": len(random_node_edge_pairs),
        "Rejected triplets": len(exclusions),
        "Queue": len(queue)
    })

    count += 1
    if count % 100 == 0:
        print("Iteration:", count)
    try:
        node = queue.pop()
    except:
        print("Finished after {} iterations.".format(count))
        break

# %%
graph_to_plot = nx.from_edgelist(random_node_edge_pairs, nx.DiGraph)

# Pickling in case we want to bring up this exact dataset again.
pickle_obj(graph_to_plot, os.path.join(PICKLED_DATA_EXPERIMENTS_DIRECTORY, "graph-{}-{}-fullgraphexperiment.pickle".format(starting_node, divisor)))

# Copying and editing visualize_random_graph helper function from src.pyvis_helpers
graph = graph_to_plot
filename = os.path.join(EXPERIMENT_IMAGE_DIRECTORY, '{}-{}.html'.format(starting_node, divisor))
g = Network(notebook=True)
#g.barnes_hut()
G_nodes = graph.nodes

# Coloring by degree -- doing a log transform since the degree of askreddit is so much larger
G_degrees = np.log([graph.degree(node) for node in G_nodes])
G_colors = nums_to_greyscale_hex(G_degrees)

for node, color in zip(G_nodes, G_colors):
    g.add_node(node, color=color)

for edge in graph.edges:
    g.add_edge(*edge)

g.show(filename)

# %% [markdown]
# # Running an experiment with the RandomSubgraph class
#
# 1. Pass in the graph, a starting node, and the divisor used to subset each nodes neighbors. (For example, a divisor of 10 means that we randomly select about 1/10th of a node's neighbors to keep.)
# 2. Call `.run_full()` to run the full experiment.
# 3. Get the `.graph_to_plot` attribute to return a NetworkX graph of the subgraph we just created.
# 4. Pass this graph, along with a number-to-color mapping function, into `get_pyvis_graph_with_colors` to get a pyvis graphing Network object returned.
# 5. Call `.show(html_filename)` on the pyvis object to display a graph in the notebook as well as save the file to the destination.

# %%
# Necessary imports
from src.random_subgraphs import RandomSubgraph
from src.pyvis_helpers import (get_pyvis_graph_with_colors, random_color,
                               map_nodes_to_random_colors, map_degrees_to_colors,
                               map_nodefunc_to_colors)

# %% [markdown]
# ## Run the Experiment

# %%
random_subgraph_experiment = RandomSubgraph(graph=G_weighted, starting_node='vegan', divisor=10)
random_subgraph_experiment.run_full()

print(random_subgraph_experiment.random_node_edge_pairs[:3])
print(len(random_subgraph_experiment.queue))
print(len(random_subgraph_experiment.exclusions))
print(random_subgraph_experiment.count)
# Out:
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Finished after 454 iterations.
# [('vegan', 'xxfitness', {'weight': 1}), ('vegan', 'backyardchickens', {'weight': 1}), ('vegan', 'quityourbullshit', {'weight': 1})]
# 0
# 5597
# 454

# %% [markdown]
# ## Pickle the graph in case we want it later

# %%
pickle_obj(random_subgraph_experiment.graph_to_plot, os.path.join(PICKLED_DATA_EXPERIMENTS_DIRECTORY, "graph-vegan-10-interesting-circle-graph.pickle"))

# %% [markdown]
# ## Graph the result

# %%
filename = os.path.join(EXPERIMENT_IMAGE_DIRECTORY, 'vegan-10-interesting-circle-graph.html')

pyvis_graph = get_pyvis_graph_with_colors(
    graph=random_subgraph_experiment.graph_to_plot,
    color_map_func=map_degrees_to_colors,
    color_map_func_kwargs={'graph': random_subgraph_experiment.graph_to_plot}
)
pyvis_graph.show(filename)
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="random_subgraphs_exp_1.0/vegan-10-interesting-circle-graph.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Running another experiment: Reddit - 10 - full graph

# %%
reddit_10_full_experiment = RandomSubgraph(
    graph=G_weighted,
    starting_node='askreddit',
    divisor=10,
    attempt_full_graph=True)

reddit_10_full_experiment.run_full()
# Out:
# Iteration: 100
# Iteration: 200
# Iteration: 300
# Iteration: 400
# Iteration: 500
# Iteration: 600
# Iteration: 700
# Iteration: 800
# Iteration: 900
# Finished after 958 iterations.

# %%
pickle_obj(reddit_10_full_experiment.graph_to_plot, os.path.join(PICKLED_DATA_EXPERIMENTS_DIRECTORY, "graph-reddit-10-full.pickle"))

# %%
filename = os.path.join(EXPERIMENT_IMAGE_DIRECTORY, 'reddit-10-full.html')

pyvis_graph = get_pyvis_graph_with_colors(
    graph=reddit_10_full_experiment.graph_to_plot,
    color_map_func=map_degrees_to_colors,
    color_map_func_kwargs={'graph': reddit_10_full_experiment.graph_to_plot}
)
pyvis_graph.show(filename)
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="random_subgraphs_exp_1.0/reddit-10-full.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Random colors visualization

# %%
filename = os.path.join(EXPERIMENT_IMAGE_DIRECTORY, 'reddit-10-full-random-colors.html')

pyvis_graph = get_pyvis_graph_with_colors(
    graph=reddit_10_full_experiment.graph_to_plot,
    color_map_func=map_nodes_to_random_colors
)

pyvis_graph.show(filename)
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="random_subgraphs_exp_1.0/reddit-10-full-random-colors.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Running another experiment - Animal Rights - 15

# %%
animalrights_15_full_experiment = RandomSubgraph(
    graph=G_weighted,
    starting_node='animalrights',
    divisor=15
)

animalrights_15_full_experiment.run_full()

pickle_obj(
    animalrights_15_full_experiment.graph_to_plot,
    os.path.join(
        PICKLED_DATA_EXPERIMENTS_DIRECTORY,
        "graph-animalrights-15.pickle"
    ))

filename = os.path.join(EXPERIMENT_IMAGE_DIRECTORY, 'animalrights-15.html')

pyvis_graph = get_pyvis_graph_with_colors(
    graph=animalrights_15_full_experiment.graph_to_plot,
    color_map_func=map_degrees_to_colors,
    color_map_func_kwargs={'graph': animalrights_15_full_experiment.graph_to_plot}
)
pyvis_graph.show(filename)
# Out:
# Finished after 92 iterations.
#         <iframe
#             width="500px"
#             height="500px"
#             src="random_subgraphs_exp_1.0/animalrights-15.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
